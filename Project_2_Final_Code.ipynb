# %% [markdown]
# # **`Project 2: Team Thomas Allinson`**

# %% [markdown]
# ### **Objective**: Analyze the comparative costs of a vegan diet versus an omnivorous diet within the American population, with a specific focus on their environmental impact.

# %% [markdown]
# #### Group Members:
# > Johann: johann.dicken@berkeley.edu <br>
# > Laure: laureho@berkeley.edu <br>
# > Reily: reilyjean@berkeley.edu <br>
# > Carmen: carmenvega@berkeley.edu <br>
# > Steven: k1519632@berkeley.edu <br>
# > Xinyu: xzhou60@berkeley.edu

# %% [markdown]
# ### **[A]: Description of population of interest**

# %% [markdown]
# The project looks at the cost differences between vegan and omnivorous diets in the U.S., focusing on their environmental impact. It examines factors like water consumption, CO2 emissions, and land use tied to different diets. Specifically, we are concentrating on the demographic of women in the 19-30 age range.

# %% [markdown]
# ### **[A]: Dietary Reference Intakes**

# %%
apikey = "KNqUDtV7Kcktiuheo3EoNhB0zDlCevFAdqZrKgdj" 
# %pip install -r requirements.txt --upgrade
# %pip install wbdata
import fooddatacentral as fdc
import pandas as pd
import numpy as np
import re
from  scipy.optimize import linprog as lp
import wbdata
import sys
import io
import warnings
warnings.simplefilter("ignore")
# Out:
# Requirement already satisfied: Pint>=0.8.1 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.24.4)
# Requirement already satisfied: numpy>=1.15.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: pandas>=0.23.3 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: requests>=2.20.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (2.32.3)
# Requirement already satisfied: scipy>=1.1.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (1.15.2)
# Requirement already satisfied: gspread in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (5.12.4)
# Collecting gspread (from -r requirements.txt (line 20))
#   Using cached gspread-6.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: gspread_pandas in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (3.3.0)
# Requirement already satisfied: bottleneck>=1.3.6 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (1.4.2)
# Requirement already satisfied: eep153_tools in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (0.12.4)
# Requirement already satisfied: fooddatacentral in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (1.0.10)
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (0.5.4)
# Requirement already satisfied: platformdirs>=2.1.0 in /srv/conda/lib/python3.11/site-packages (from Pint>=0.8.1->-r requirements.txt (line 2)) (4.3.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /srv/conda/lib/python3.11/site-packages (from Pint>=0.8.1->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: flexcache>=0.3 in /srv/conda/lib/python3.11/site-packages (from Pint>=0.8.1->-r requirements.txt (line 2)) (0.3)
# Requirement already satisfied: flexparser>=0.4 in /srv/conda/lib/python3.11/site-packages (from Pint>=0.8.1->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23.3->-r requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23.3->-r requirements.txt (line 11)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23.3->-r requirements.txt (line 11)) (2025.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.20.0->-r requirements.txt (line 15)) (2025.1.31)
# Requirement already satisfied: google-auth>=1.12.0 in /srv/conda/lib/python3.11/site-packages (from gspread->-r requirements.txt (line 20)) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /srv/conda/lib/python3.11/site-packages (from gspread->-r requirements.txt (line 20)) (1.2.1)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from gspread_pandas->-r requirements.txt (line 22)) (5.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from google-auth>=1.12.0->gspread->-r requirements.txt (line 20)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from google-auth>=1.12.0->gspread->-r requirements.txt (line 20)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/lib/python3.11/site-packages (from google-auth>=1.12.0->gspread->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.11/site-packages (from google-auth-oauthlib>=0.4.1->gspread->-r requirements.txt (line 20)) (2.0.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.23.3->-r requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /srv/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread->-r requirements.txt (line 20)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread->-r requirements.txt (line 20)) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting wbdata
#   Using cached wbdata-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting appdirs<2.0,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3.0.0,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6.0.0,>=5.3.2 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.5.2)
# Collecting dateparser<2.0.0,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.2.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: decorator<6.0.0,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3.0,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4.0,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<0.9.0,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.8.10-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2.9.0.post0)
# Collecting pytz>=2024.2 (from dateparser<2.0.0,>=1.2.0->wbdata)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.11.6)
# Collecting tzlocal>=0.2 (from dateparser<2.0.0,>=1.2.0->wbdata)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2.0.0,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.0.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached dateparser-1.2.1-py3-none-any.whl (295 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.8.10-py3-none-any.whl (29 kB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: pytz, appdirs, tzlocal, tabulate, shelved-cache, dateparser, wbdata
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# linearmodels 0.0.0 requires Cython>=3.0.10, which is not installed.
# linearmodels 0.0.0 requires setuptools-scm[toml]<9.0.0,>=8.0.0, which is not installed.
# Successfully installed appdirs-1.4.4 dateparser-1.2.1 pytz-2025.1 shelved-cache-0.3.1 tabulate-0.8.10 tzlocal-5.3.1 wbdata-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# Key '-8425757781385910434' not in persistent cache.
# Key '-6328244939392091704' not in persistent cache.
# Key '-4906688266838026165' not in persistent cache.
# Key '2302672503663627930' not in persistent cache.
# Key '-7791158547164459863' not in persistent cache.
# Key '-1224287270423344626' not in persistent cache.
# Key '1454991038176768522' not in persistent cache.
# Key '4719823140175326828' not in persistent cache.
# Key '8153464607044295535' not in persistent cache.
# Key '-3187326623915242381' not in persistent cache.
# Key '-773189302352772594' not in persistent cache.
# Key '-5068402819630993665' not in persistent cache.
# Key '-6854567352562103294' not in persistent cache.
# Key '7810979534511149803' not in persistent cache.
# Key '-3426403768696747718' not in persistent cache.
# Key '-7116695024650517544' not in persistent cache.
# Key '2714833157937866561' not in persistent cache.
# Key '-8068721430788758621' not in persistent cache.
# Key '-6647164758234693082' not in persistent cache.
# Key '6851062868833820439' not in persistent cache.
# Key '8272619541387885978' not in persistent cache.
# Key '-2964763761820011543' not in persistent cache.
# Key '5388149261061452280' not in persistent cache.
# Key '554305752727872726' not in persistent cache.
# Key '-3812445227306870951' not in persistent cache.
# Key '-547613125308312645' not in persistent cache.
# Key '2886028341560656062' not in persistent cache.
# Key '-8454762889398881854' not in persistent cache.
# Key '-4098016170976172774' not in persistent cache.
# Key '-3994872305270025717' not in persistent cache.
# Key '8267349852524048142' not in persistent cache.
# Key '4486152665887749623' not in persistent cache.
# Key '-6751230637320147898' not in persistent cache.
# Key '8005222180435633892' not in persistent cache.
# Key '3788363672298834509' not in persistent cache.
# Key '7053195774297392815' not in persistent cache.
# Key '-5573634243873725134' not in persistent cache.
# Key '3526236000210420259' not in persistent cache.
# Key '4947792672764485798' not in persistent cache.
# Key '-6289590630443411723' not in persistent cache.
# Key '9109351681072908925' not in persistent cache.
# Key '-2770521115895527454' not in persistent cache.
# Key '-7137272095930271131' not in persistent cache.
# Key '525917389052655303' not in persistent cache.
# Key '-438798527062744118' not in persistent cache.
# Key '6667154315687269582' not in persistent cache.
# Key '-6493856862005135712' not in persistent cache.
# Key '5010001788775706136' not in persistent cache.
# Key '-1174520127139771621' not in persistent cache.
# Key '6488669357843154813' not in persistent cache.
# Key '6652000839709952083' not in persistent cache.
# Key '2961709583756182257' not in persistent cache.
# Key '-5653506307364985254' not in persistent cache.
# Key '2009683177617941180' not in persistent cache.
# Key '3431239850172006719' not in persistent cache.
# Key '5528752692165825449' not in persistent cache.
# Key '6950309364719890988' not in persistent cache.
# Key '7113640846586688258' not in persistent cache.
# Key '4065839084393457290' not in persistent cache.
# Key '-7814033712574979089' not in persistent cache.
# Key '-5134755403974865941' not in persistent cache.
# Key '-8915952590611164460' not in persistent cache.
# Key '1563718164892661072' not in persistent cache.
# Key '1623641719007817947' not in persistent cache.
# Key '-44299866286559668' not in persistent cache.
# Key '-6987185289215269436' not in persistent cache.
# Key '5275036868578804423' not in persistent cache.
# Key '-5508517720147820759' not in persistent cache.
# Key '-2697514332630534792' not in persistent cache.
# Key '-9035477494234793315' not in persistent cache.
# Key '7842079976988447615' not in persistent cache.
# Key '8459240173336517224' not in persistent cache.
# Key '-8565947227818968853' not in persistent cache.
# Key '-6468434385825150123' not in persistent cache.
# Key '-5046877713271084584' not in persistent cache.
# Key '2162483057230569511' not in persistent cache.
# Key '-7931347993597518282' not in persistent cache.
# Key '-1364476716856403045' not in persistent cache.
# Key '1314801591743710103' not in persistent cache.
# Key '4579633693742268409' not in persistent cache.
# Key '3614917777626868988' not in persistent cache.
# Key '-3327516070348300800' not in persistent cache.
# Key '-9043100171844923388' not in persistent cache.
# Key '-8939956306138776331' not in persistent cache.
# Key '7720623234639665656' not in persistent cache.
# Key '3939426048003367137' not in persistent cache.
# Key '-7297957255204530384' not in persistent cache.
# Key '7458495562551251406' not in persistent cache.
# Key '-1156720328569916105' not in persistent cache.
# Key '6506469156413010329' not in persistent cache.
# Key '7928025828967075868' not in persistent cache.
# Key '2979509382326037773' not in persistent cache.
# Key '-6999648730194591479' not in persistent cache.
# Key '-6836317248327794209' not in persistent cache.
# Key '8562625063188526439' not in persistent cache.
# Key '-3317247733779909940' not in persistent cache.
# Key '-7683998713814653617' not in persistent cache.
# Key '-4419166611816095311' not in persistent cache.
# Key '6060504143687730221' not in persistent cache.
# Key '6120427697802887096' not in persistent cache.
# Key '8813707545182318673' not in persistent cache.
# Key '1626088349065862677' not in persistent cache.
# Key '8648682386407084756' not in persistent cache.
# Key '-2692560419505993140' not in persistent cache.
# Key '-4478724952437102769' not in persistent cache.
# Key '-1213892850438544463' not in persistent cache.
# Key '-1050561368571747193' not in persistent cache.
# Key '-4740852624525517019' not in persistent cache.
# Key '5090675558062867086' not in persistent cache.
# Key '-5692879030663758096' not in persistent cache.
# Key '-4271322358109692557' not in persistent cache.
# Key '-2173809516115873827' not in persistent cache.
# Key '-752252843561808288' not in persistent cache.
# Key '6457107926939845807' not in persistent cache.
# Key '-3636723123888241986' not in persistent cache.
# Key '2930148152852873251' not in persistent cache.
# Key '5609426461452986399' not in persistent cache.
# Key '6226586657801056008' not in persistent cache.
# Key '-6138844043389038204' not in persistent cache.
# Key '-6078920489273881329' not in persistent cache.
# Key '95889580146498751' not in persistent cache.
# Key '-6846995842782211017' not in persistent cache.
# Key '5415226315011862842' not in persistent cache.
# Key '-5368328273714762340' not in persistent cache.
# Key '-5204996791847965070' not in persistent cache.
# Key '-8895288047801734896' not in persistent cache.
# Key '936240134786649209' not in persistent cache.
# Key '8599429619769575643' not in persistent cache.
# Key '-8425757781385910434' not in persistent cache.
# Key '-6328244939392091704' not in persistent cache.
# Key '-4906688266838026165' not in persistent cache.
# Key '2302672503663627930' not in persistent cache.
# Key '-7791158547164459863' not in persistent cache.
# Key '-1224287270423344626' not in persistent cache.
# Key '1454991038176768522' not in persistent cache.
# Key '4719823140175326828' not in persistent cache.
# Key '8153464607044295535' not in persistent cache.
# Key '-3187326623915242381' not in persistent cache.
# Key '-773189302352772594' not in persistent cache.
# Key '-5068402819630993665' not in persistent cache.
# Key '-6854567352562103294' not in persistent cache.
# Key '7810979534511149803' not in persistent cache.
# Key '-3426403768696747718' not in persistent cache.
# Key '-7116695024650517544' not in persistent cache.
# Key '2714833157937866561' not in persistent cache.
# Key '-8068721430788758621' not in persistent cache.
# Key '-6647164758234693082' not in persistent cache.
# Key '6851062868833820439' not in persistent cache.
# Key '8272619541387885978' not in persistent cache.
# Key '-2964763761820011543' not in persistent cache.
# Key '5388149261061452280' not in persistent cache.
# Key '554305752727872726' not in persistent cache.
# Key '-3812445227306870951' not in persistent cache.
# Key '-547613125308312645' not in persistent cache.
# Key '2886028341560656062' not in persistent cache.
# Key '-8454762889398881854' not in persistent cache.
# Key '-4098016170976172774' not in persistent cache.
# Key '-3994872305270025717' not in persistent cache.
# Key '8267349852524048142' not in persistent cache.
# Key '4486152665887749623' not in persistent cache.
# Key '-6751230637320147898' not in persistent cache.
# Key '371430887590907674' not in persistent cache.
# Key '8034620372573834108' not in persistent cache.
# Key '7069904456458434687' not in persistent cache.
# Key '-4270886774501103229' not in persistent cache.
# Key '-8264468980448045262' not in persistent cache.
# Key '-2934361990443332933' not in persistent cache.
# Key '-968706004480377907' not in persistent cache.
# Key '2757747305823791598' not in persistent cache.
# Key '-3039261127773139217' not in persistent cache.
# Key '-5240962903764264798' not in persistent cache.
# Key '-8055757359581454444' not in persistent cache.
# Key '1039857719868113144' not in persistent cache.
# Key '-8420760676982382126' not in persistent cache.
# Key '-5978034916769951081' not in persistent cache.
# Key '1206699884591129006' not in persistent cache.
# Key '-1266731866118045138' not in persistent cache.
# Key '-3574289797534352598' not in persistent cache.
# Key '-6170874186548391917' not in persistent cache.
# Key '2235769957526542593' not in persistent cache.
# Key '-7815340887601360212' not in persistent cache.
# Key '5058163047290364766' not in persistent cache.
# Key '2373274970073202452' not in persistent cache.
# Key '139940663821605875' not in persistent cache.
# Key '-2542926360734978850' not in persistent cache.
# Key '90832148608032028' not in persistent cache.
# Key '3396661296928075079' not in persistent cache.
# Key '3912764190827845487' not in persistent cache.
# Key '-1328864763861141484' not in persistent cache.
# Key '6686613708511623483' not in persistent cache.
# Key '-7871516249990041966' not in persistent cache.
# Key '-4033567867985306727' not in persistent cache.
# Key '2258990196575129089' not in persistent cache.
# Key '5095031532008287766' not in persistent cache.
# Key '115192798739653004' not in persistent cache.
# Key '-3715295457222064120' not in persistent cache.
# Key '5235651484343758341' not in persistent cache.
# Key '1221329948406352394' not in persistent cache.
# Key '-7798544145008013694' not in persistent cache.
# Key '-5647917029769103691' not in persistent cache.
# Key '1670520238631027813' not in persistent cache.
# Key '4403825243775294977' not in persistent cache.
# Key '-410079515092281310' not in persistent cache.
# Key '1867746707515799704' not in persistent cache.
# Key '4583491746735837472' not in persistent cache.
# Key '-516463271136490039' not in persistent cache.
# Key '-6306582515281786931' not in persistent cache.
# Key '678735848728558868' not in persistent cache.
# Key '5695270583630735953' not in persistent cache.
# Key '-3298837285304897629' not in persistent cache.
# Key '8503876776535225691' not in persistent cache.
# Key '2204511034773785756' not in persistent cache.
# Key '-7305816061449936569' not in persistent cache.
# Key '-532684282712450402' not in persistent cache.
# Key '-7485009540494662004' not in persistent cache.
# Key '-330644659262313293' not in persistent cache.
# Key '3413513558868748792' not in persistent cache.
# Key '8736420944135663232' not in persistent cache.
# Key '3951896418043393926' not in persistent cache.
# Key '8289355883968956753' not in persistent cache.
# Key '2216629397421251502' not in persistent cache.
# Key '4274523985506565238' not in persistent cache.
# Key '3225145805833441858' not in persistent cache.
# Key '2030732970272501997' not in persistent cache.
# Key '-7877725459672343140' not in persistent cache.
# Key '-2095168026481299666' not in persistent cache.
# Key '-5636681928319699983' not in persistent cache.
# Key '1674247258046550150' not in persistent cache.
# Key '-3101437750603181599' not in persistent cache.
# Key '-4090272527626450413' not in persistent cache.
# Key '-8087871622640238936' not in persistent cache.
# Key '-69524781105317588' not in persistent cache.
# Key '-4547638589011819826' not in persistent cache.
# Key '115043626448773980' not in persistent cache.
# Key '-5748381634289843378' not in persistent cache.
# Key '-5136510230780435138' not in persistent cache.
# Key '8902618678824827435' not in persistent cache.
# Key '-2026413870775989993' not in persistent cache.
# Key '-7885039177112260045' not in persistent cache.
# Key '8845884592674507006' not in persistent cache.
# Key '-2036726414905489945' not in persistent cache.
# Key '-6012388144308242695' not in persistent cache.
# Key '8224863902653612600' not in persistent cache.
# Key '-6148760177348526274' not in persistent cache.
# Key '-4754332952674534782' not in persistent cache.
# Key '-2851940763342875279' not in persistent cache.
# Key '-1292939049877326152' not in persistent cache.
# Key '994569006344534596' not in persistent cache.
# Key '-1604235481514259978' not in persistent cache.
# Key '-2561995775912951268' not in persistent cache.
# Key '-7571839284466776566' not in persistent cache.
# Key '-1422939625441179742' not in persistent cache.
# Key '-7458700908036869225' not in persistent cache.
# Key '6672796606925465997' not in persistent cache.
# Key '-5550702110164761135' not in persistent cache.
# Key '-7609835947089147471' not in persistent cache.
# Key '-6165289818248001153' not in persistent cache.
# Key '8826950395700851240' not in persistent cache.
# Key '85148646407005129' not in persistent cache.
# Key '-8714739340386610338' not in persistent cache.
# Key '7269484289162404361' not in persistent cache.
# Key '8199062409603288145' not in persistent cache.
# Key '-7271879880657453244' not in persistent cache.
# Key '-7168736014951306187' not in persistent cache.
# Key '5093486142842767672' not in persistent cache.
# Key '5710646339190837281' not in persistent cache.
# Key '8521649726708123248' not in persistent cache.
# Key '-9217028219970830066' not in persistent cache.
# Key '614499962617554039' not in persistent cache.
# Key '8277689447600480473' not in persistent cache.
# Key '-8747497953555005604' not in persistent cache.
# Key '4750729673513507917' not in persistent cache.
# Key '-5228428439007121335' not in persistent cache.
# Key '-5065096957140324065' not in persistent cache.
# Key '-8112898719333555033' not in persistent cache.
# Key '-1546027442592439796' not in persistent cache.
# Key '1133250866007673352' not in persistent cache.
# Key '-2647946320628625167' not in persistent cache.
# Key '3433367051890832237' not in persistent cache.
# Key '7891647988990357240' not in persistent cache.
# Key '4039511609934593993' not in persistent cache.
# Key '4142655475640741050' not in persistent cache.
# Key '-2041866440274736707' not in persistent cache.
# Key '-5823063626911035226' not in persistent cache.
# Key '1386297143590618869' not in persistent cache.
# Key '-2303994112363150957' not in persistent cache.
# Key '-6520852620499950340' not in persistent cache.
# Key '-3256020518501392034' not in persistent cache.
# Key '-1834463845947326495' not in persistent cache.
# Key '-6782980292588364590' not in persistent cache.
# Key '-5361423620034299051' not in persistent cache.
# Key '1847937150467355044' not in persistent cache.
# Key '-1199864611725875924' not in persistent cache.
# Key '5367006665015239313' not in persistent cache.
# Key '1000255684980495636' not in persistent cache.
# Key '8663445169963422070' not in persistent cache.
# Key '7698729253848022649' not in persistent cache.
# Key '-3642061977111515267' not in persistent cache.
# Key '7706043832383397110' not in persistent cache.
# Key '7809187698089544167' not in persistent cache.
# Key '1624665782174066410' not in persistent cache.
# Key '2241825978522136019' not in persistent cache.
# Key '5052829366039421986' not in persistent cache.
# Key '5760895493070020288' not in persistent cache.
# Key '-2854320398051147223' not in persistent cache.
# Key '410511703947411083' not in persistent cache.
# Key '6230425759485844750' not in persistent cache.
# Key '-3116448070139561473' not in persistent cache.
# Key '2703465985398872194' not in persistent cache.
# Key '5514469372916158161' not in persistent cache.
# Key '2466667610722927193' not in persistent cache.
# Key '9033538887464042430' not in persistent cache.
# Key '4666787907429298753' not in persistent cache.
# Key '-6116766681297326429' not in persistent cache.
# Key '-7081482597412725850' not in persistent cache.
# Key '24470245337287850' not in persistent cache.
# Key '-1011783918741447068' not in persistent cache.
# Key '-7954669341670156836' not in persistent cache.
# Key '4307552816123917023' not in persistent cache.
# Key '-6476001772602708159' not in persistent cache.
# Key '-6312670290735910889' not in persistent cache.
# Key '8443782527019870901' not in persistent cache.
# Key '-171433364101296610' not in persistent cache.
# Key '7491756120881629824' not in persistent cache.
# Key '8913312793435695363' not in persistent cache.
# Key '-7435918438280037523' not in persistent cache.
# Key '-6014361765725971984' not in persistent cache.
# Key '-5851030283859174714' not in persistent cache.
# Key '-8898832046052405682' not in persistent cache.
# Key '-2331960769311290445' not in persistent cache.
# Key '347317539288822703' not in persistent cache.
# Key '-3433879647347475816' not in persistent cache.
# Key '2647433725171981588' not in persistent cache.
# Key '7105714662271506591' not in persistent cache.
# Key '3946090778329458768' not in persistent cache.
# Key '-8717456341021031126' not in persistent cache.
# Key '3244123427135052764' not in persistent cache.
# Key '2319189977411472816' not in persistent cache.
# Key '5410521647275698446' not in persistent cache.
# Key '9143876874526808367' not in persistent cache.
# Key '6615459582493183646' not in persistent cache.
# Key '-8877973593428632292' not in persistent cache.
# Key '-3690302522278967128' not in persistent cache.
# Key '-8880517349808519660' not in persistent cache.
# Key '-240565365582539916' not in persistent cache.
# Key '867947889191365920' not in persistent cache.
# Key '-1782461923937911142' not in persistent cache.
# Key '-1190175661103380470' not in persistent cache.
# Key '-2849691462131615360' not in persistent cache.
# Key '3854983117521155589' not in persistent cache.
# Key '-7513224587666594668' not in persistent cache.
# Key '839872776483462539' not in persistent cache.
# Key '3812658342424153355' not in persistent cache.
# Key '-3432375835405719284' not in persistent cache.
# Key '7901356252767672706' not in persistent cache.
# Key '-4658683221448576999' not in persistent cache.
# Key '4246024964926749386' not in persistent cache.
# Key '797848191045022820' not in persistent cache.
# Key '601149765972063573' not in persistent cache.
# Key '8324324428256397332' not in persistent cache.
# Key '2307585816212430988' not in persistent cache.
# Key '-8086145046098956235' not in persistent cache.
# Key '-8541516831333505200' not in persistent cache.
# Key '-4982976914224386927' not in persistent cache.
# Key '-3944646011338717211' not in persistent cache.
# Key '3075779247430873238' not in persistent cache.
# Key '-2569680576093030572' not in persistent cache.
# Key '-7755622084022368407' not in persistent cache.
# Key '7156608769111474383' not in persistent cache.
# Key '-3819975562703706555' not in persistent cache.
# Key '3536362877640919293' not in persistent cache.
# Key '6749285174780591411' not in persistent cache.
# Key '1123562185141610928' not in persistent cache.
# Key '-2447760019191205265' not in persistent cache.
# Key '6870067238774089815' not in persistent cache.
# Key '5469838924369078988' not in persistent cache.
# Key '-3774463190893758212' not in persistent cache.
# Key '1495550942064263334' not in persistent cache.
# Key '-8569022144915940056' not in persistent cache.
# Key '4648565592918403540' not in persistent cache.
# Key '7886806850046644161' not in persistent cache.
# Key '4166408439194561024' not in persistent cache.
# Key '-8793546352924682687' not in persistent cache.
# Key '-4595622499815813101' not in persistent cache.
# Key '2496515532655447505' not in persistent cache.
# Key '516920341232413714' not in persistent cache.
# Key '-7914471240542875303' not in persistent cache.
# Key '732415823531439018' not in persistent cache.
# Key '2392833855396544156' not in persistent cache.
# Key '3629834505414199427' not in persistent cache.
# Key '-297349867917754335' not in persistent cache.
# Key '5511491717494273224' not in persistent cache.
# Key '-2888840213936314851' not in persistent cache.
# Key '-400517119522948850' not in persistent cache.
# Key '-7878039352349261003' not in persistent cache.
# Key '5476158023663536563' not in persistent cache.
# Key '-4647185689453336260' not in persistent cache.
# Key '7548793362592936508' not in persistent cache.
# Key '1120884046738616814' not in persistent cache.
# Key '-835460883314939694' not in persistent cache.
# Key '-5274401722144461297' not in persistent cache.
# Key '-3961380735141960628' not in persistent cache.
# Key '7291625285251423349' not in persistent cache.
# Key '4531765493007326147' not in persistent cache.
# Key '1900627651639260666' not in persistent cache.
# Key '3998181811973735023' not in persistent cache.
# Key '4759467927321488848' not in persistent cache.
# Key '-8441706924117676179' not in persistent cache.
# Key '-6100941201399396581' not in persistent cache.
# Key '819444906466519285' not in persistent cache.
# Key '9111462396801862610' not in persistent cache.
# Key '1455642518914720134' not in persistent cache.
# Key '7967784329184847111' not in persistent cache.
# Key '3107416431029704397' not in persistent cache.
# Key '-1832973723816075628' not in persistent cache.
# Key '3752075291231112155' not in persistent cache.
# Key '-8061066087207580561' not in persistent cache.
# Key '6432874019319275966' not in persistent cache.
# Key '-2160857558180157167' not in persistent cache.
# Key '6900333793510537463' not in persistent cache.
# Key '-8053396880437743606' not in persistent cache.
# Key '3901820176816060109' not in persistent cache.
# Key '5349930730421604971' not in persistent cache.
# Key '2387699681825251312' not in persistent cache.
# Key '-8777749168185651758' not in persistent cache.
# Key '3028153277761673656' not in persistent cache.
# Key '-1612913835567679801' not in persistent cache.
# Key '-6012523356734704928' not in persistent cache.
# Key '-3383693752243704713' not in persistent cache.
# Key '8187105516926215164' not in persistent cache.
# Key '-5843836107911064355' not in persistent cache.
# Key '-1942889588610799642' not in persistent cache.
# Key '-4095452387714652969' not in persistent cache.
# Key '-547667268612924124' not in persistent cache.
# Key '-2634035429252580678' not in persistent cache.
# Key '-2468405575642734105' not in persistent cache.
# Key '-5375128417768504141' not in persistent cache.
# Key '-3538660334962822865' not in persistent cache.
# Key '-968084195592264649' not in persistent cache.
# Key '407206571878718555' not in persistent cache.
# Key '-5685624593301622691' not in persistent cache.
# Key '-2377207240112788026' not in persistent cache.
# Key '-7261341368604064308' not in persistent cache.
# Key '8542591468266515177' not in persistent cache.
# Key '-8745217724983994580' not in persistent cache.
# Key '4552148376512159406' not in persistent cache.
# Key '7313619519344493751' not in persistent cache.
# Key '2062951552161303549' not in persistent cache.
# Key '7596340341380388952' not in persistent cache.
# Key '4167181276641257980' not in persistent cache.
# Key '-7571839284466776566' not in persistent cache.
# Key '-7458700908036869225' not in persistent cache.
# Key '2887636220580668926' not in persistent cache.
# Key '-8658477655626469813' not in persistent cache.
# Key '-8087871622640238936' not in persistent cache.
# Key '-69524781105317588' not in persistent cache.
# Key '-4547638589011819826' not in persistent cache.
# Key '115043626448773980' not in persistent cache.
# Key '-5748381634289843378' not in persistent cache.
# Key '-5136510230780435138' not in persistent cache.
# Key '-2144632454331671701' not in persistent cache.
# Key '5578803407738198123' not in persistent cache.
# Key '2329445976561124367' not in persistent cache.
# Key '8092597554910167373' not in persistent cache.
# Key '4808574840121179465' not in persistent cache.
# Key '-2463193266341222055' not in persistent cache.
# Key '5522422504137034161' not in persistent cache.
# Key '-6815415828892441541' not in persistent cache.
# Key '2371770237870078292' not in persistent cache.
# Key '-2643235451560455827' not in persistent cache.
# Key '-5844659317626469810' not in persistent cache.
# Key '3642352529991843801' not in persistent cache.
# Key '-1366487851994772819' not in persistent cache.
# Key '-6474357393044207316' not in persistent cache.
# Key '-3785374970325563580' not in persistent cache.
# Key '-1422939625441179742' not in persistent cache.
# Key '6672796606925465997' not in persistent cache.
# Key '5438429596423939764' not in persistent cache.
# Key '108620028722738648' not in persistent cache.
# Key '-2776917472409536572' not in persistent cache.
# Key '2642654355403738881' not in persistent cache.
# Key '8181423161058316705' not in persistent cache.
# Key '4770240804332270805' not in persistent cache.
# Key '7779416876652917662' not in persistent cache.
# Key '578036135272677221' not in persistent cache.
# Key '7090482733636661586' not in persistent cache.
# Key '-2311490022848248810' not in persistent cache.
# Key '7398752409628608807' not in persistent cache.
# Key '-1777457253531011440' not in persistent cache.
# Key '-4734290066982075899' not in persistent cache.
# Key '-8698205130166662902' not in persistent cache.
# Key '-6987870909310630853' not in persistent cache.
# Key '1491908485010297898' not in persistent cache.
# Key '-4420791963226209287' not in persistent cache.
# Key '-6431273256894493014' not in persistent cache.
# Key '-6009003403737432446' not in persistent cache.
# Key '7470172463740681475' not in persistent cache.
# Key '-429028716842783249' not in persistent cache.
# Key '3248315403293525542' not in persistent cache.
# Key '7727598406801262546' not in persistent cache.
# Key '-3638647244667346490' not in persistent cache.
# Key '6234126860687887264' not in persistent cache.
# Key '-5692115822656826235' not in persistent cache.
# Key '7737882053400682396' not in persistent cache.
# Key '-5774904472830369458' not in persistent cache.
# Key '-4488098436635880847' not in persistent cache.
# Key '-1873934310641838621' not in persistent cache.
# Key '-2032184925747959251' not in persistent cache.
# Key '3288590944528507408' not in persistent cache.
# Key '-7679620260311557426' not in persistent cache.
# Key '-7745617746697089370' not in persistent cache.
# Key '-4468208672944998895' not in persistent cache.
# Key '3573180373535729279' not in persistent cache.
# Key '8014567524840985525' not in persistent cache.
# Key '-6196012662117586039' not in persistent cache.
# Key '-5385729957250995981' not in persistent cache.
# Key '-1220155884055474887' not in persistent cache.
# Key '-3810321856049894347' not in persistent cache.
# Key '3396661296928075079' not in persistent cache.
# Key '3912764190827845487' not in persistent cache.
# Key '-1328864763861141484' not in persistent cache.
# Key '6686613708511623483' not in persistent cache.
# Key '-7871516249990041966' not in persistent cache.
# Key '-4033567867985306727' not in persistent cache.
# Key '2258990196575129089' not in persistent cache.
# Key '5095031532008287766' not in persistent cache.
# Key '115192798739653004' not in persistent cache.
# Key '-3715295457222064120' not in persistent cache.
# Key '5235651484343758341' not in persistent cache.
# Key '1221329948406352394' not in persistent cache.
# Key '-7798544145008013694' not in persistent cache.
# Key '-5647917029769103691' not in persistent cache.
# Key '1670520238631027813' not in persistent cache.
# Key '4403825243775294977' not in persistent cache.
# Key '-410079515092281310' not in persistent cache.
# Key '1867746707515799704' not in persistent cache.
# Key '4583491746735837472' not in persistent cache.
# Key '-516463271136490039' not in persistent cache.
# Key '-6306582515281786931' not in persistent cache.
# Key '-3420769180652193813' not in persistent cache.
# Key '-436684488257953190' not in persistent cache.
# Key '-6723398450397393712' not in persistent cache.
# Key '5711510697321426378' not in persistent cache.
# Key '3901820176816060109' not in persistent cache.
# Key '5349930730421604971' not in persistent cache.
# Key '2387699681825251312' not in persistent cache.
# Key '-8777749168185651758' not in persistent cache.
# Key '3028153277761673656' not in persistent cache.
# Key '-1612913835567679801' not in persistent cache.
# Key '-6012523356734704928' not in persistent cache.
# Key '-3383693752243704713' not in persistent cache.
# Key '8187105516926215164' not in persistent cache.
# Key '-5843836107911064355' not in persistent cache.
# Key '-1942889588610799642' not in persistent cache.
# Key '-4095452387714652969' not in persistent cache.
# Key '1003511565143173956' not in persistent cache.
# Key '5353765796926267666' not in persistent cache.
# Key '-1275019087483275579' not in persistent cache.
# Key '1358940126770799498' not in persistent cache.
# Key '3556750210814648085' not in persistent cache.
# Key '-8499772357441005517' not in persistent cache.
# Key '2311587171228152403' not in persistent cache.
# Key '-6004314215250303071' not in persistent cache.
# Key '6566124238578010401' not in persistent cache.
# Key '-6829607904734515289' not in persistent cache.
# Key '-3647724541542107190' not in persistent cache.
# Key '2056496893313786920' not in persistent cache.
# Key '-3330931732911655430' not in persistent cache.
# Key '-3763360564804604370' not in persistent cache.
# Key '7661142109699329908' not in persistent cache.
# Key '2847742887236366016' not in persistent cache.
# Key '5423876392650790845' not in persistent cache.
# Key '-1258619145008568431' not in persistent cache.
# Key '8151267335634824759' not in persistent cache.
# Key '1440778314137830568' not in persistent cache.
# Key '-8591569187609339661' not in persistent cache.
# Key '4819519013140490564' not in persistent cache.
# Key '4864900520206181440' not in persistent cache.
# Key '-5822967685594843144' not in persistent cache.
# Key '8275449328057753496' not in persistent cache.
# Key '6343617631405502339' not in persistent cache.
# Key '-8061066087207580561' not in persistent cache.
# Key '6432874019319275966' not in persistent cache.
# Key '-2160857558180157167' not in persistent cache.
# Key '6900333793510537463' not in persistent cache.
# Key '-8053396880437743606' not in persistent cache.
# Key '-547667268612924124' not in persistent cache.
# Key '-2634035429252580678' not in persistent cache.
# Key '-2468405575642734105' not in persistent cache.
# Key '-5375128417768504141' not in persistent cache.
# Key '-3538660334962822865' not in persistent cache.
# Key '-968084195592264649' not in persistent cache.
# Key '407206571878718555' not in persistent cache.
# Key '-5685624593301622691' not in persistent cache.
# Key '-2377207240112788026' not in persistent cache.
# Key '-7261341368604064308' not in persistent cache.
# Key '8542591468266515177' not in persistent cache.
# Key '-8745217724983994580' not in persistent cache.
# Key '4552148376512159406' not in persistent cache.
# Key '7313619519344493751' not in persistent cache.
# Key '2062951552161303549' not in persistent cache.
# Key '7596340341380388952' not in persistent cache.
# Key '4167181276641257980' not in persistent cache.
# Key '2195119502894778292' not in persistent cache.
# Key '8536049974347448497' not in persistent cache.
# Key '6358639658781297925' not in persistent cache.
# Key '-7273875454327126686' not in persistent cache.
# Key '100611896890854257' not in persistent cache.
# Key '-8724908190815877129' not in persistent cache.
# Key '5666252055081029961' not in persistent cache.
# Key '4214216943607225054' not in persistent cache.
# Key '1303306043685143258' not in persistent cache.
# Key '-7845016234832232571' not in persistent cache.
# Key '6457343238943524949' not in persistent cache.
# Key '-4020524715360814033' not in persistent cache.
# Key '8444152105878761785' not in persistent cache.
# Key '8987501195484396206' not in persistent cache.
# Key '-8713061719343086355' not in persistent cache.
# Key '-3172606386250293319' not in persistent cache.
# Key '-117404904990924656' not in persistent cache.
# Key '7607048901824517839' not in persistent cache.
# Key '-7831338034282695133' not in persistent cache.
# Key '5658804912210557131' not in persistent cache.
# Key '-1615171739859364223' not in persistent cache.
# Key '8409098297864611421' not in persistent cache.
# Key '-3747789132227006166' not in persistent cache.
# Key '-5971538250311559221' not in persistent cache.
# Key '216690630115319268' not in persistent cache.
# Key '-7148197902182125960' not in persistent cache.
# Key '-4915792009404865234' not in persistent cache.
# Key '-1270385267138643270' not in persistent cache.
# Key '-2940543330277889478' not in persistent cache.
# Key '5784514311648812074' not in persistent cache.
# Key '-2909790281799972365' not in persistent cache.
# Key '5788523066892148724' not in persistent cache.
# Key '408860936588151993' not in persistent cache.
# Key '4242830687661703839' not in persistent cache.
# Key '3396661296928075079' not in persistent cache.
# Key '3912764190827845487' not in persistent cache.
# Key '-1328864763861141484' not in persistent cache.
# Key '6686613708511623483' not in persistent cache.
# Key '-7871516249990041966' not in persistent cache.
# Key '-4033567867985306727' not in persistent cache.
# Key '2258990196575129089' not in persistent cache.
# Key '5095031532008287766' not in persistent cache.
# Key '115192798739653004' not in persistent cache.
# Key '-3715295457222064120' not in persistent cache.
# Key '5235651484343758341' not in persistent cache.
# Key '1221329948406352394' not in persistent cache.
# Key '-7798544145008013694' not in persistent cache.
# Key '-5647917029769103691' not in persistent cache.
# Key '1670520238631027813' not in persistent cache.
# Key '-5774904472830369458' not in persistent cache.
# Key '-4488098436635880847' not in persistent cache.
# Key '-1873934310641838621' not in persistent cache.
# Key '-2032184925747959251' not in persistent cache.
# Key '3288590944528507408' not in persistent cache.
# Key '-7679620260311557426' not in persistent cache.
# Key '4403825243775294977' not in persistent cache.
# Key '-410079515092281310' not in persistent cache.
# Key '1867746707515799704' not in persistent cache.
# Key '4583491746735837472' not in persistent cache.
# Key '-516463271136490039' not in persistent cache.
# Key '-6306582515281786931' not in persistent cache.
# Key '-3420769180652193813' not in persistent cache.
# Key '-436684488257953190' not in persistent cache.
# Key '-6723398450397393712' not in persistent cache.
# Key '5711510697321426378' not in persistent cache.
# Key '5349930730421604971' not in persistent cache.
# Key '2387699681825251312' not in persistent cache.
# Key '-8777749168185651758' not in persistent cache.
# Key '3028153277761673656' not in persistent cache.
# Key '-1612913835567679801' not in persistent cache.
# Key '-6012523356734704928' not in persistent cache.
# Key '-3383693752243704713' not in persistent cache.
# Key '8187105516926215164' not in persistent cache.
# Key '-5843836107911064355' not in persistent cache.
# Key '-1942889588610799642' not in persistent cache.
# Key '-4095452387714652969' not in persistent cache.
# Key '-7745617746697089370' not in persistent cache.
# Key '-4468208672944998895' not in persistent cache.
# Key '3573180373535729279' not in persistent cache.
# Key '8014567524840985525' not in persistent cache.
# Key '-6196012662117586039' not in persistent cache.
# Key '-5385729957250995981' not in persistent cache.
# Key '-1220155884055474887' not in persistent cache.
# Key '-3810321856049894347' not in persistent cache.
# Key '-7242516534584888478' not in persistent cache.
# Key '-8061066087207580561' not in persistent cache.
# Key '6432874019319275966' not in persistent cache.
# Key '-2160857558180157167' not in persistent cache.
# Key '6900333793510537463' not in persistent cache.
# Key '-8053396880437743606' not in persistent cache.
# Key '8949065811027446348' not in persistent cache.
# Key '3901820176816060109' not in persistent cache.
# Key '6343617631405502339' not in persistent cache.
# Key '-318529787902409001' not in persistent cache.
# Key '8275449328057753496' not in persistent cache.
# Key '-547667268612924124' not in persistent cache.
# Key '-2634035429252580678' not in persistent cache.
# Key '-2468405575642734105' not in persistent cache.
# Key '-5375128417768504141' not in persistent cache.
# Key '-3538660334962822865' not in persistent cache.
# Key '-968084195592264649' not in persistent cache.
# Key '407206571878718555' not in persistent cache.
# Key '-5685624593301622691' not in persistent cache.
# Key '-2377207240112788026' not in persistent cache.
# Key '-7261341368604064308' not in persistent cache.
# Key '8542591468266515177' not in persistent cache.
# Key '-8745217724983994580' not in persistent cache.
# Key '4552148376512159406' not in persistent cache.
# Key '7313619519344493751' not in persistent cache.
# Key '2062951552161303549' not in persistent cache.
# Key '7596340341380388952' not in persistent cache.
# Key '4167181276641257980' not in persistent cache.
# Key '8474370099678336319' not in persistent cache.
# Key '1531484676749626551' not in persistent cache.
# Key '-4653037239165851206' not in persistent cache.
# Key '-8425757781385910434' not in persistent cache.
# Key '-6328244939392091704' not in persistent cache.
# Key '-4906688266838026165' not in persistent cache.
# Key '2302672503663627930' not in persistent cache.
# Key '-7791158547164459863' not in persistent cache.
# Key '-1224287270423344626' not in persistent cache.
# Key '1454991038176768522' not in persistent cache.
# Key '4719823140175326828' not in persistent cache.
# Key '8153464607044295535' not in persistent cache.
# Key '-3187326623915242381' not in persistent cache.
# Key '-773189302352772594' not in persistent cache.
# Key '-5068402819630993665' not in persistent cache.
# Key '-6854567352562103294' not in persistent cache.
# Key '7810979534511149803' not in persistent cache.
# Key '-3426403768696747718' not in persistent cache.
# Key '-7116695024650517544' not in persistent cache.
# Key '2714833157937866561' not in persistent cache.
# Key '-8068721430788758621' not in persistent cache.
# Key '-6647164758234693082' not in persistent cache.
# Key '6851062868833820439' not in persistent cache.
# Key '8272619541387885978' not in persistent cache.
# Key '-2964763761820011543' not in persistent cache.
# Key '5388149261061452280' not in persistent cache.
# Key '554305752727872726' not in persistent cache.
# Key '-3812445227306870951' not in persistent cache.
# Key '-547613125308312645' not in persistent cache.
# Key '2886028341560656062' not in persistent cache.
# Key '-8454762889398881854' not in persistent cache.
# Key '-4098016170976172774' not in persistent cache.
# Key '-3994872305270025717' not in persistent cache.
# Key '8267349852524048142' not in persistent cache.
# Key '4486152665887749623' not in persistent cache.
# Key '-6751230637320147898' not in persistent cache.
# Key '8005222180435633892' not in persistent cache.
# Key '3788363672298834509' not in persistent cache.
# Key '7053195774297392815' not in persistent cache.
# Key '-5573634243873725134' not in persistent cache.
# Key '3526236000210420259' not in persistent cache.
# Key '4947792672764485798' not in persistent cache.
# Key '-6289590630443411723' not in persistent cache.
# Key '9109351681072908925' not in persistent cache.
# Key '-2770521115895527454' not in persistent cache.
# Key '-7137272095930271131' not in persistent cache.
# Key '525917389052655303' not in persistent cache.
# Key '-438798527062744118' not in persistent cache.
# Key '6667154315687269582' not in persistent cache.
# Key '-6493856862005135712' not in persistent cache.
# Key '5010001788775706136' not in persistent cache.
# Key '-1174520127139771621' not in persistent cache.
# Key '6488669357843154813' not in persistent cache.
# ...
# Key '-8441706924117676179' not in persistent cache.
# Key '-6100941201399396581' not in persistent cache.
# Key '819444906466519285' not in persistent cache.
# Key '9111462396801862610' not in persistent cache.
# Key '1455642518914720134' not in persistent cache.
# Key '7967784329184847111' not in persistent cache.
# Key '3107416431029704397' not in persistent cache.
# Key '-1832973723816075628' not in persistent cache.
# Key '3752075291231112155' not in persistent cache.
# Key '-8061066087207580561' not in persistent cache.
# Key '6432874019319275966' not in persistent cache.
# Key '-2160857558180157167' not in persistent cache.
# Key '6900333793510537463' not in persistent cache.
# Key '-8053396880437743606' not in persistent cache.
# Key '3901820176816060109' not in persistent cache.
# Key '5349930730421604971' not in persistent cache.
# Key '2387699681825251312' not in persistent cache.
# Key '-8777749168185651758' not in persistent cache.
# Key '3028153277761673656' not in persistent cache.
# Key '-1612913835567679801' not in persistent cache.
# Key '-6012523356734704928' not in persistent cache.
# Key '-3383693752243704713' not in persistent cache.
# Key '8187105516926215164' not in persistent cache.
# Key '-5843836107911064355' not in persistent cache.
# Key '-1942889588610799642' not in persistent cache.
# Key '-4095452387714652969' not in persistent cache.
# Key '-547667268612924124' not in persistent cache.
# Key '-2634035429252580678' not in persistent cache.
# Key '-2468405575642734105' not in persistent cache.
# Key '-5375128417768504141' not in persistent cache.
# Key '-3538660334962822865' not in persistent cache.
# Key '-968084195592264649' not in persistent cache.
# Key '407206571878718555' not in persistent cache.
# Key '-5685624593301622691' not in persistent cache.
# Key '-2377207240112788026' not in persistent cache.
# Key '-7261341368604064308' not in persistent cache.
# Key '8542591468266515177' not in persistent cache.
# Key '-8745217724983994580' not in persistent cache.
# Key '4552148376512159406' not in persistent cache.
# Key '7313619519344493751' not in persistent cache.
# Key '2062951552161303549' not in persistent cache.
# Key '7596340341380388952' not in persistent cache.
# Key '4167181276641257980' not in persistent cache.
# Key '-7571839284466776566' not in persistent cache.
# Key '-7458700908036869225' not in persistent cache.
# Key '2887636220580668926' not in persistent cache.
# Key '-8658477655626469813' not in persistent cache.
# Key '-8087871622640238936' not in persistent cache.
# Key '-69524781105317588' not in persistent cache.
# Key '-4547638589011819826' not in persistent cache.
# Key '115043626448773980' not in persistent cache.
# Key '-5748381634289843378' not in persistent cache.
# Key '-5136510230780435138' not in persistent cache.
# Key '-2144632454331671701' not in persistent cache.
# Key '5578803407738198123' not in persistent cache.
# Key '2329445976561124367' not in persistent cache.
# Key '8092597554910167373' not in persistent cache.
# Key '4808574840121179465' not in persistent cache.
# Key '-2463193266341222055' not in persistent cache.
# Key '5522422504137034161' not in persistent cache.
# Key '-6815415828892441541' not in persistent cache.
# Key '2371770237870078292' not in persistent cache.
# Key '-2643235451560455827' not in persistent cache.
# Key '-5844659317626469810' not in persistent cache.
# Key '3642352529991843801' not in persistent cache.
# Key '-1366487851994772819' not in persistent cache.
# Key '-6474357393044207316' not in persistent cache.
# Key '-3785374970325563580' not in persistent cache.
# Key '-1422939625441179742' not in persistent cache.
# Key '6672796606925465997' not in persistent cache.
# Key '5438429596423939764' not in persistent cache.
# Key '108620028722738648' not in persistent cache.
# Key '-2776917472409536572' not in persistent cache.
# Key '2642654355403738881' not in persistent cache.
# Key '8181423161058316705' not in persistent cache.
# Key '4770240804332270805' not in persistent cache.
# Key '7779416876652917662' not in persistent cache.
# Key '578036135272677221' not in persistent cache.
# Key '7090482733636661586' not in persistent cache.
# Key '-2311490022848248810' not in persistent cache.
# Key '7398752409628608807' not in persistent cache.
# Key '-1777457253531011440' not in persistent cache.
# Key '-4734290066982075899' not in persistent cache.
# Key '-8698205130166662902' not in persistent cache.
# Key '-6987870909310630853' not in persistent cache.
# Key '1491908485010297898' not in persistent cache.
# Key '-4420791963226209287' not in persistent cache.
# Key '-6431273256894493014' not in persistent cache.
# Key '-6009003403737432446' not in persistent cache.
# Key '7470172463740681475' not in persistent cache.
# Key '-429028716842783249' not in persistent cache.
# Key '3248315403293525542' not in persistent cache.
# Key '7727598406801262546' not in persistent cache.
# Key '-3638647244667346490' not in persistent cache.
# Key '6234126860687887264' not in persistent cache.
# Key '-5692115822656826235' not in persistent cache.
# Key '7737882053400682396' not in persistent cache.
# Key '-5774904472830369458' not in persistent cache.
# Key '-4488098436635880847' not in persistent cache.
# Key '-1873934310641838621' not in persistent cache.
# Key '-2032184925747959251' not in persistent cache.
# Key '3288590944528507408' not in persistent cache.
# Key '-7679620260311557426' not in persistent cache.
# Key '-7745617746697089370' not in persistent cache.
# Key '-4468208672944998895' not in persistent cache.
# Key '3573180373535729279' not in persistent cache.
# Key '8014567524840985525' not in persistent cache.
# Key '-6196012662117586039' not in persistent cache.
# Key '-5385729957250995981' not in persistent cache.
# Key '-1220155884055474887' not in persistent cache.
# Key '-3810321856049894347' not in persistent cache.
# Key '3396661296928075079' not in persistent cache.
# Key '3912764190827845487' not in persistent cache.
# Key '-1328864763861141484' not in persistent cache.
# Key '6686613708511623483' not in persistent cache.
# Key '-7871516249990041966' not in persistent cache.
# Key '-4033567867985306727' not in persistent cache.
# Key '2258990196575129089' not in persistent cache.
# Key '5095031532008287766' not in persistent cache.
# Key '115192798739653004' not in persistent cache.
# Key '-3715295457222064120' not in persistent cache.
# Key '5235651484343758341' not in persistent cache.
# Key '1221329948406352394' not in persistent cache.
# Key '-7798544145008013694' not in persistent cache.
# Key '-5647917029769103691' not in persistent cache.
# Key '1670520238631027813' not in persistent cache.
# Key '4403825243775294977' not in persistent cache.
# Key '-410079515092281310' not in persistent cache.
# Key '1867746707515799704' not in persistent cache.
# Key '4583491746735837472' not in persistent cache.
# Key '-516463271136490039' not in persistent cache.
# Key '-6306582515281786931' not in persistent cache.
# Key '-3420769180652193813' not in persistent cache.
# Key '-436684488257953190' not in persistent cache.
# Key '-6723398450397393712' not in persistent cache.
# Key '5711510697321426378' not in persistent cache.
# Key '3901820176816060109' not in persistent cache.
# Key '5349930730421604971' not in persistent cache.
# Key '2387699681825251312' not in persistent cache.
# Key '-8777749168185651758' not in persistent cache.
# Key '3028153277761673656' not in persistent cache.
# Key '-1612913835567679801' not in persistent cache.
# Key '-6012523356734704928' not in persistent cache.
# Key '-3383693752243704713' not in persistent cache.
# Key '8187105516926215164' not in persistent cache.
# Key '-5843836107911064355' not in persistent cache.
# Key '-1942889588610799642' not in persistent cache.
# Key '-4095452387714652969' not in persistent cache.
# Key '1003511565143173956' not in persistent cache.
# Key '5353765796926267666' not in persistent cache.
# Key '-1275019087483275579' not in persistent cache.
# Key '1358940126770799498' not in persistent cache.
# Key '3556750210814648085' not in persistent cache.
# Key '-8499772357441005517' not in persistent cache.
# Key '2311587171228152403' not in persistent cache.
# Key '-6004314215250303071' not in persistent cache.
# Key '6566124238578010401' not in persistent cache.
# Key '-6829607904734515289' not in persistent cache.
# Key '-3647724541542107190' not in persistent cache.
# Key '2056496893313786920' not in persistent cache.
# Key '-3330931732911655430' not in persistent cache.
# Key '-3763360564804604370' not in persistent cache.
# Key '7661142109699329908' not in persistent cache.
# Key '2847742887236366016' not in persistent cache.
# Key '5423876392650790845' not in persistent cache.
# Key '-1258619145008568431' not in persistent cache.
# Key '8151267335634824759' not in persistent cache.
# Key '1440778314137830568' not in persistent cache.
# Key '-8591569187609339661' not in persistent cache.
# Key '4819519013140490564' not in persistent cache.
# Key '4864900520206181440' not in persistent cache.
# Key '-5822967685594843144' not in persistent cache.
# Key '8275449328057753496' not in persistent cache.
# Key '6343617631405502339' not in persistent cache.
# Key '-8061066087207580561' not in persistent cache.
# Key '6432874019319275966' not in persistent cache.
# Key '-2160857558180157167' not in persistent cache.
# Key '6900333793510537463' not in persistent cache.
# Key '-8053396880437743606' not in persistent cache.
# Key '-547667268612924124' not in persistent cache.
# Key '-2634035429252580678' not in persistent cache.
# Key '-2468405575642734105' not in persistent cache.
# Key '-5375128417768504141' not in persistent cache.
# Key '-3538660334962822865' not in persistent cache.
# Key '-968084195592264649' not in persistent cache.
# Key '407206571878718555' not in persistent cache.
# Key '-5685624593301622691' not in persistent cache.
# Key '-2377207240112788026' not in persistent cache.
# Key '-7261341368604064308' not in persistent cache.
# Key '8542591468266515177' not in persistent cache.
# Key '-8745217724983994580' not in persistent cache.
# Key '4552148376512159406' not in persistent cache.
# Key '7313619519344493751' not in persistent cache.
# Key '2062951552161303549' not in persistent cache.
# Key '7596340341380388952' not in persistent cache.
# Key '4167181276641257980' not in persistent cache.
# Key '2195119502894778292' not in persistent cache.
# Key '8536049974347448497' not in persistent cache.
# Key '6358639658781297925' not in persistent cache.
# Key '-7273875454327126686' not in persistent cache.
# Key '100611896890854257' not in persistent cache.
# Key '-8724908190815877129' not in persistent cache.
# Key '5666252055081029961' not in persistent cache.
# Key '4214216943607225054' not in persistent cache.
# Key '1303306043685143258' not in persistent cache.
# Key '-7845016234832232571' not in persistent cache.
# Key '6457343238943524949' not in persistent cache.
# Key '-4020524715360814033' not in persistent cache.
# Key '8444152105878761785' not in persistent cache.
# Key '8987501195484396206' not in persistent cache.
# Key '-8713061719343086355' not in persistent cache.
# Key '-3172606386250293319' not in persistent cache.
# Key '-117404904990924656' not in persistent cache.
# Key '7607048901824517839' not in persistent cache.
# Key '-7831338034282695133' not in persistent cache.
# Key '5658804912210557131' not in persistent cache.
# Key '-1615171739859364223' not in persistent cache.
# Key '8409098297864611421' not in persistent cache.
# Key '-3747789132227006166' not in persistent cache.
# Key '-5971538250311559221' not in persistent cache.
# Key '216690630115319268' not in persistent cache.
# Key '-7148197902182125960' not in persistent cache.
# Key '-4915792009404865234' not in persistent cache.
# Key '-1270385267138643270' not in persistent cache.
# Key '-2940543330277889478' not in persistent cache.
# Key '5784514311648812074' not in persistent cache.
# Key '-2909790281799972365' not in persistent cache.
# Key '5788523066892148724' not in persistent cache.
# Key '408860936588151993' not in persistent cache.
# Key '4242830687661703839' not in persistent cache.
# Key '3396661296928075079' not in persistent cache.
# Key '3912764190827845487' not in persistent cache.
# Key '-1328864763861141484' not in persistent cache.
# Key '6686613708511623483' not in persistent cache.
# Key '-7871516249990041966' not in persistent cache.
# Key '-4033567867985306727' not in persistent cache.
# Key '2258990196575129089' not in persistent cache.
# Key '5095031532008287766' not in persistent cache.
# Key '115192798739653004' not in persistent cache.
# Key '-3715295457222064120' not in persistent cache.
# Key '5235651484343758341' not in persistent cache.
# Key '1221329948406352394' not in persistent cache.
# Key '-7798544145008013694' not in persistent cache.
# Key '-5647917029769103691' not in persistent cache.
# Key '1670520238631027813' not in persistent cache.
# Key '-5774904472830369458' not in persistent cache.
# Key '-4488098436635880847' not in persistent cache.
# Key '-1873934310641838621' not in persistent cache.
# Key '-2032184925747959251' not in persistent cache.
# Key '3288590944528507408' not in persistent cache.
# Key '-7679620260311557426' not in persistent cache.
# Key '4403825243775294977' not in persistent cache.
# Key '-410079515092281310' not in persistent cache.
# Key '1867746707515799704' not in persistent cache.
# Key '4583491746735837472' not in persistent cache.
# Key '-516463271136490039' not in persistent cache.
# Key '-6306582515281786931' not in persistent cache.
# Key '-3420769180652193813' not in persistent cache.
# Key '-436684488257953190' not in persistent cache.
# Key '-6723398450397393712' not in persistent cache.
# Key '5711510697321426378' not in persistent cache.
# Key '5349930730421604971' not in persistent cache.
# Key '2387699681825251312' not in persistent cache.
# Key '-8777749168185651758' not in persistent cache.
# Key '3028153277761673656' not in persistent cache.
# Key '-1612913835567679801' not in persistent cache.
# Key '-6012523356734704928' not in persistent cache.
# Key '-3383693752243704713' not in persistent cache.
# Key '8187105516926215164' not in persistent cache.
# Key '-5843836107911064355' not in persistent cache.
# Key '-1942889588610799642' not in persistent cache.
# Key '-4095452387714652969' not in persistent cache.
# Key '-7745617746697089370' not in persistent cache.
# Key '-4468208672944998895' not in persistent cache.
# Key '3573180373535729279' not in persistent cache.
# Key '8014567524840985525' not in persistent cache.
# Key '-6196012662117586039' not in persistent cache.
# Key '-5385729957250995981' not in persistent cache.
# Key '-1220155884055474887' not in persistent cache.
# Key '-3810321856049894347' not in persistent cache.
# Key '-7242516534584888478' not in persistent cache.
# Key '-8061066087207580561' not in persistent cache.
# Key '6432874019319275966' not in persistent cache.
# Key '-2160857558180157167' not in persistent cache.
# Key '6900333793510537463' not in persistent cache.
# Key '-8053396880437743606' not in persistent cache.
# Key '8949065811027446348' not in persistent cache.
# Key '3901820176816060109' not in persistent cache.
# Key '6343617631405502339' not in persistent cache.
# Key '-318529787902409001' not in persistent cache.
# Key '8275449328057753496' not in persistent cache.
# Key '-547667268612924124' not in persistent cache.
# Key '-2634035429252580678' not in persistent cache.
# Key '-2468405575642734105' not in persistent cache.
# Key '-5375128417768504141' not in persistent cache.
# Key '-3538660334962822865' not in persistent cache.
# Key '-968084195592264649' not in persistent cache.
# Key '407206571878718555' not in persistent cache.
# Key '-5685624593301622691' not in persistent cache.
# Key '-2377207240112788026' not in persistent cache.
# Key '-7261341368604064308' not in persistent cache.
# Key '8542591468266515177' not in persistent cache.
# Key '-8745217724983994580' not in persistent cache.
# Key '4552148376512159406' not in persistent cache.
# Key '7313619519344493751' not in persistent cache.
# Key '2062951552161303549' not in persistent cache.
# Key '7596340341380388952' not in persistent cache.
# Key '4167181276641257980' not in persistent cache.
# Key '8474370099678336319' not in persistent cache.
# Key '1531484676749626551' not in persistent cache.
# Key '-4653037239165851206' not in persistent cache.

# %%
# Import Dietary Requirements spreadsheet data as a pd.DataFrame
diet_min = pd.read_csv('Dietary_Requirements.csv')
diet_min.head()
# Out:
#               Nutrition Source   C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# 0                Energy    ---  1000.0  1200.0  1400.0  1600.0  1800.0
# 1               Protein    RDA    13.0    19.0    19.0    34.0    34.0
# 2  Fiber, total dietary    ---    14.0    16.8    19.6    22.4    25.2
# 3           Folate, DFE    RDA   150.0   200.0   200.0   300.0   300.0
# 4           Calcium, Ca    RDA   700.0  1000.0  1000.0  1300.0  1300.0
#
#    F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  M 31-50   F 51+   M 51+
# 0   1800.0   2200.0   2000.0   2400.0   1800.0   2200.0  1600.0  2000.0
# 1     46.0     52.0     46.0     56.0     46.0     56.0    46.0    56.0
# 2     25.2     30.8     28.0     33.6     25.2     30.8    22.4    28.0
# 3    400.0    400.0    400.0    400.0    400.0    400.0   400.0   400.0
# 4   1300.0   1300.0   1000.0   1000.0   1000.0   1000.0  1200.0  1000.0

# %% [markdown]
# Dietary function takes 2 arguments: `age`, a positive integer, and `sex`, a string (not case-senstitive) with the classification of male, female, or child.

# %%
def dietary_ref(age, sex):

    # Validate age input
    if not isinstance(age, int) or age <= 0:
        return "Incorrect age input. Please enter a positive integer for the age."
    
    # Normalize and validate sex input
    sex = sex.lower()
    if sex not in ['male', 'female', 'child']:
        return "Incorrect sex input. Input must be Male, Female, or Child."
    
    # Determine the appropriate column based on age and sex
    if sex == 'child':
        if age <= 3:
            col_name = 'C 1-3'
        elif age <= 8:
            col_name = 'C 4-8'
        else:
            return "Age out of range for child category."
    else:
        if age <= 8:
            col_name = f"{'F' if sex == 'female' else 'M'} 4-8"
        elif age <= 13:
            col_name = f"{'F' if sex == 'female' else 'M'} 9-13"
        elif age <= 18:
            col_name = f"{'F' if sex == 'female' else 'M'} 14-18"
        elif age <= 30:
            col_name = f"{'F' if sex == 'female' else 'M'} 19-30"
        elif age <= 50:
            col_name = f"{'F' if sex == 'female' else 'M'} 31-50"
        else:
            col_name = f"{'F' if sex == 'female' else 'M'} 51+"
    
    # Extract and return the relevant nutrient recommendations
    if col_name in diet_min.columns:
        return diet_min[['Nutrition', col_name]].set_index('Nutrition')[col_name]
    else:
        return "Matching column not found in DataFrame. Check the column names."

# %%
# Example usage
dietary_ref(15, 'Male')
# Out:
# Nutrition
# Energy                            2200.0
# Protein                             52.0
# Fiber, total dietary                30.8
# Folate, DFE                        400.0
# Calcium, Ca                       1300.0
# Carbohydrate, by difference        130.0
# Iron, Fe                            11.0
# Magnesium, Mg                      410.0
# Niacin                              16.0
# Phosphorus, P                     1250.0
# Potassium, K                      4700.0
# Riboflavin                           1.3
# Thiamin                              1.2
# Vitamin A, RAE                     900.0
# Vitamin B-12                         2.4
# Vitamin B-6                          1.3
# Vitamin C, total ascorbic acid      75.0
# Vitamin E (alpha-tocopherol)        15.0
# Vitamin K (phylloquinone)           75.0
# Zinc, Zn                            11.0
# Name: M 14-18, dtype: float64

# %%
# Unit test: verify column name matches the expected group
assert dietary_ref(15, 'Male').name == 'M 14-18'

# %% [markdown]
# ### **[A]: Data on prices for different foods**

# %% [markdown]
# > ### OMNIVORE DIET

# %% [markdown]
# DataFrame of 126 different foods, with data on their carbon and water footprints, average price, and vegan classification: `animal product` or `plant-based`.

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('food_and_prices.csv')

# Define a regex pattern for common animal products
animal_product_pattern = r'\b(butter|cheese|milk|kefir|whey|eggnog|mascarpone|mozzarella|stracchino|parmigiano|beef|turbot|cod|ricotta|chicken|carp|salmon|bacon|trout|mealworms|dulce|pork|egg|fish|lamb|turkey|turtle|breast|mollusks|frog|thigh|yogurt|honey|gelatin|cream|lard|sausage|anchovy|shellfish|shrimp|mayo|ham|meat)\b'

# Create a new column 'animal product' that marks items based on the pattern
df['animal product'] = df['Food commodity ITEM'].apply(
    lambda x: 'animal product' if re.search(animal_product_pattern, str(x), re.IGNORECASE) else 'plant-based'
)

# Display the updated DataFrame
df.rename(columns={'Food commodity ITEM': 'Food'}, inplace=True)
df = df[df['Food'] != 'YEAST COMPRESSED*']
df['Average Price per 100g (USD)'] = df['Average Price per kg (USD)']/10
#df.drop('YEAST COMPRESSED*'
#df[df['animal product'] == 'plant-based'].head(100)
df.set_index('Food', inplace=True)
df.head()
# Out:
#                                      Carbon Footprint kg CO2eq/kg or l of food ITEM  \
# Food
# CHOCOLATE OR CREAM FILLED COOKIES**                                            1.53
# SIMPLE COOKIES**                                                               1.39
# BREAD MULTICEREAL**                                                            0.70
# BREAD PLAIN**                                                                  0.89
# BREAD WHOLE**                                                                  0.77
#
#                                      Water Footprint liters water/kg o liter of food ITEM  \
# Food
# CHOCOLATE OR CREAM FILLED COOKIES**                                             2902.0
# SIMPLE COOKIES**                                                                1723.0
# BREAD MULTICEREAL**                                                              771.0
# BREAD PLAIN**                                                                   1031.0
# BREAD WHOLE**                                                                    887.0
#
#                                       FDC ID               FDC Food Name  \
# Food
# CHOCOLATE OR CREAM FILLED COOKIES**  2707915  Cookie, chocolate or fudge
# SIMPLE COOKIES**                     2707964          Cookie, shortbread
# BREAD MULTICEREAL**                  2707777           Bread, multigrain
# BREAD PLAIN**                         174929        Bread, sticks, plain
# BREAD WHOLE**                        2707709          Bread, whole wheat
#
#                                      Average Price per kg (USD)  \
# Food
# CHOCOLATE OR CREAM FILLED COOKIES**                       10.80
# SIMPLE COOKIES**                                          10.80
# BREAD MULTICEREAL**                                        4.24
# BREAD PLAIN**                                              4.24
# BREAD WHOLE**                                              4.24
#
#                                      animal product  \
# Food
# CHOCOLATE OR CREAM FILLED COOKIES**  animal product
# SIMPLE COOKIES**                        plant-based
# BREAD MULTICEREAL**                     plant-based
# BREAD PLAIN**                           plant-based
# BREAD WHOLE**                           plant-based
#
#                                      Average Price per 100g (USD)
# Food
# CHOCOLATE OR CREAM FILLED COOKIES**                         1.080
# SIMPLE COOKIES**                                            1.080
# BREAD MULTICEREAL**                                         0.424
# BREAD PLAIN**                                               0.424
# BREAD WHOLE**                                               0.424

# %% [markdown]
# ### **[A]: Nutritional content of different foods**

# %% [markdown]
# Returns DataFrame of nutrient values for all foods we are evaluating.

# %%
D = {}
count = 0
for food in df.index:
        try:
            FDC = df.loc[df.index==food,:]['FDC ID'][0]
            count+=1
            D[food] = fdc.nutrients(apikey,FDC).Quantity
            #print(D[food])
            #print(food)
        except AttributeError:
            warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")
    
D = pd.DataFrame(D,dtype=float)
D
# Out:
#                                   CHOCOLATE OR CREAM FILLED COOKIES**  \
# Alanine                                                           NaN
# Alcohol, ethyl                                                   0.00
# Amino acids                                                       NaN
# Arginine                                                          NaN
# Ash                                                               NaN
# ...                                                               ...
# Vitamin K (Dihydrophylloquinone)                                  NaN
# Vitamin K (phylloquinone)                                        2.40
# Vitamins and Other Components                                     NaN
# Water                                                            4.50
# Zinc, Zn                                                         1.09
#
#                                   SIMPLE COOKIES**  BREAD MULTICEREAL**  \
# Alanine                                        NaN                  NaN
# Alcohol, ethyl                                0.00                  0.0
# Amino acids                                    NaN                  NaN
# Arginine                                       NaN                  NaN
# Ash                                            NaN                  NaN
# ...                                            ...                  ...
# Vitamin K (Dihydrophylloquinone)               NaN                  NaN
# Vitamin K (phylloquinone)                    11.00                  1.4
# Vitamins and Other Components                  NaN                  NaN
# Water                                         3.60                 36.9
# Zinc, Zn                                      0.49                  1.7
#
#                                   BREAD PLAIN**  BREAD WHOLE**  \
# Alanine                                   0.395            NaN
# Alcohol, ethyl                            0.000           0.00
# Amino acids                               0.000            NaN
# Arginine                                  0.432            NaN
# Ash                                       3.900            NaN
# ...                                         ...            ...
# Vitamin K (Dihydrophylloquinone)            NaN            NaN
# Vitamin K (phylloquinone)                 2.200           7.80
# Vitamins and Other Components             0.000            NaN
# Water                                     6.100          38.70
# Zinc, Zn                                  0.880           1.76
#
#                                   FLAVORED CRACKERS**  PLAIN CRACKERS**  \
# Alanine                                           NaN               NaN
# Alcohol, ethyl                                    NaN              0.00
# Amino acids                                       NaN               NaN
# Arginine                                          NaN               NaN
# Ash                                               NaN               NaN
# ...                                               ...               ...
# Vitamin K (Dihydrophylloquinone)                  NaN               NaN
# Vitamin K (phylloquinone)                         NaN             69.30
# Vitamins and Other Components                     NaN               NaN
# Water                                             NaN              3.14
# Zinc, Zn                                          NaN              0.49
#
#                                   WHOLEGRAIN CRACKERS**  CRISPBREAD**  \
# Alanine                                             NaN           NaN
# Alcohol, ethyl                                     0.00           NaN
# Amino acids                                         NaN           NaN
# Arginine                                            NaN           NaN
# Ash                                                 NaN           NaN
# ...                                                 ...           ...
# Vitamin K (Dihydrophylloquinone)                    NaN           NaN
# Vitamin K (phylloquinone)                         36.00           NaN
# Vitamins and Other Components                       NaN           NaN
# Water                                              2.50           NaN
# Zinc, Zn                                           0.98           NaN
#
#                                   KETCHUP  ...  EGGPLANT  PEPPER  PUMPKIN  \
# Alanine                               NaN  ...       NaN     NaN      NaN
# Alcohol, ethyl                       0.00  ...      0.00     NaN      NaN
# Amino acids                           NaN  ...       NaN     NaN      NaN
# Arginine                              NaN  ...       NaN     NaN      NaN
# Ash                                   NaN  ...       NaN     NaN      NaN
# ...                                   ...  ...       ...     ...      ...
# Vitamin K (Dihydrophylloquinone)      NaN  ...       NaN     NaN      NaN
# Vitamin K (phylloquinone)            3.00  ...     24.30     NaN      NaN
# Vitamins and Other Components         NaN  ...       NaN     NaN      NaN
# Water                               68.50  ...     70.40     NaN      NaN
# Zinc, Zn                             0.16  ...      1.36     NaN      NaN
#
#                                   TOMATO  ZUCCHINI   CARP  COD  SALMON  TROUT  \
# Alanine                              NaN       NaN    NaN  NaN     NaN    NaN
# Alcohol, ethyl                       NaN       NaN   0.00  NaN     NaN   0.00
# Amino acids                          NaN       NaN    NaN  NaN     NaN    NaN
# Arginine                             NaN       NaN    NaN  NaN     NaN    NaN
# Ash                                  NaN       NaN    NaN  NaN     NaN    NaN
# ...                                  ...       ...    ...  ...     ...    ...
# Vitamin K (Dihydrophylloquinone)     NaN       NaN    NaN  NaN     NaN    NaN
# Vitamin K (phylloquinone)            NaN       NaN   4.00  NaN     NaN  12.00
# Vitamins and Other Components        NaN       NaN    NaN  NaN     NaN    NaN
# Water                                NaN       NaN  60.50  NaN     NaN  53.20
# Zinc, Zn                             NaN       NaN   1.65  NaN     NaN   0.49
#
#                                   TURBOT
# Alanine                            0.971
# Alcohol, ethyl                       NaN
# Amino acids                        0.000
# Arginine                           0.960
# Ash                                2.100
# ...                                  ...
# Vitamin K (Dihydrophylloquinone)     NaN
# Vitamin K (phylloquinone)            NaN
# Vitamins and Other Components      0.000
# Water                             76.950
# Zinc, Zn                           0.220
#
# [133 rows x 126 columns]

# %% [markdown]
# ### **[A]: Solution**

# %% [markdown]
# Returns DataFrame of the minimum and maximum values for each nutrient for each sex-age group.

# %%
bmin = diet_min.set_index('Nutrition', inplace= True)

bmin = diet_min
bmin = bmin.drop('Source',axis=1)
#bmax
bmax = pd.read_csv('diet_max.csv')
bmax = bmax.drop('Source',axis=1) #
bmax = bmax.set_index('Nutrition')

#bmin
b = pd.concat([bmin,-bmax]) # Note sign change for max constraints

b
# Out:
#                                  C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                          1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              14.0    16.8    19.6    22.4    25.2
# Folate, DFE                      150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                      700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference      130.0   130.0   130.0   130.0   130.0
# Iron, Fe                           7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     80.0   130.0   130.0   240.0   240.0
# Niacin                             6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                    460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                    3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                         0.5     0.6     0.6     0.9     0.9
# Thiamin                            0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                       0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                        0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)       6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)         30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                           3.0     5.0     5.0     8.0     8.0
# Sodium, Na                     -1500.0 -1900.0 -1900.0 -2200.0 -2200.0
# Energy                         -2500.0 -2500.0 -2500.0 -2800.0 -3000.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
# Sodium, Na                      -2300.0  -2300.0  -2300.0  -2300.0  -2300.0
# Energy                          -3100.0  -3100.0  -3100.0  -3100.0  -3100.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0
# Sodium, Na                      -2300.0 -2300.0 -2300.0
# Energy                          -3100.0 -3100.0 -3100.0

# %% [markdown]
# Function that returns the total minimum cost per day of a diet based on the following inputs: <br>
# > `sex-age group`: gender and age classification as in Dietary Requirements columns (ex: "M 14-18") <br>
# > `diet`: classification of vegan or omnivore <br>
# > `df`: DataFrame of foods with their respective values

# %%
def get_grub(sex_age_group, diet, df, price_column):
    # Filter for vegan/plant-based diets if needed
    if diet in ['vegan', 'plant-based']:
        df = df[df['animal product'] == 'plant-based']
    
    # Build nutrient dictionary
    D = {}
    for food in df.index:
        try:
            FDC = df.loc[df.index == food, 'FDC ID'].iloc[0]
            D[food] = fdc.nutrients(apikey, FDC).Quantity
        except AttributeError:
            warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")
    
    D = pd.DataFrame(D, dtype=float)
    df = df.dropna(how='any')  # Drop foods with any missing data

    # Set up two price series based on the column provided:
    if price_column == 'Water Footprint liters water/kg o liter of food ITEM':
        # Use water footprint for optimization
        Prices_opt = df.groupby('Food')[price_column].min()
        p_optimization = Prices_opt.dropna()
        # And use average price for cost calculation
        Prices_cost = df.groupby('Food')['Average Price per 100g (USD)'].min()
        p_cost = Prices_cost.dropna()
    else:
        # Otherwise, use the provided column for both
        Prices = df.groupby('Food')[price_column].min()
        p_optimization = Prices.dropna()
        p_cost = p_optimization.copy()

    # Compile list that we have both prices and nutritional info for; drop if either missing
    use = p_optimization.index.intersection(D.columns)
    p_optimization = p_optimization[use]
    p_cost = p_cost[use]
    
    tol = 1e-6  # Tolerance for nearly zero quantities

    # Build nutrient matrix; Aall has rows as nutrient constraints and columns as foods
    Aall = D[p_optimization.index].fillna(0)
    # bmin and bmax are assumed to be defined outside this function
    Amin = Aall.loc[bmin.index]
    Amax = Aall.loc[bmax.index]
    # Form the constraint matrix A (note the sign change for maximum constraints)
    A = pd.concat([Amin, -Amax])

    # Solve the LP (assumes lp() is a defined linear programming function)
    result = lp(p_optimization, -A, -b[sex_age_group], method='highs')
    
    # Convert solution to a nicely labeled Series
    diet_quantities = pd.Series(result.x, index=p_optimization.index)
    
    # Calculate cost: if using water footprint for optimization, re-calculate cost using p_cost
    if price_column == 'Water Footprint liters water/kg o liter of food ITEM':
        total_cost = (diet_quantities * p_cost).sum()
        constraint = "Water footprint"
    elif price_column == 'Price with Co2 Social Cost per 100g (USD)':
        total_cost = result.fun
        constraint = 'C02 social cost'
    else:
        total_cost = result.fun
        constraint = 'only price minimums'
    
    print(f"Cost of diet for {sex_age_group} with a(n) {diet} diet, controlling for {constraint} is ${total_cost:.2f} per day.")
    print("\nYou'll be eating (in 100s of grams or milliliters):")
    print(diet_quantities[diet_quantities >= tol])
    
    return diet_quantities, total_cost

# %%
#Omnivore Diet
group = "F 19-30"
diet = 'omnivore'
#result = get_grub(group, diet, df)
price_col = 'Average Price per 100g (USD)'
solution = get_grub(group, diet, df, price_col)
# Out:
# Cost of diet for F 19-30 with a(n) omnivore diet, controlling for only price minimums is $3.30 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# CARROT           1.285283
# COW MILK         3.514002
# COWPEA           1.668872
# LETTUCE          0.503611
# OAT              0.763807
# POTATO           3.113865
# SOY BURGER       1.194030
# SOYBEAN          1.389350
# SUNFLOWER OIL    0.189099
# dtype: float64

# %%
#Vegan Diet
group = "F 19-30"
diet = 'vegan'
#result = get_grub(group, diet, df)
price_col = 'Average Price per 100g (USD)'
solution = get_grub(group, diet, df, price_col)
# Out:
# Cost of diet for F 19-30 with a(n) vegan diet, controlling for only price minimums is $3.36 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# CARROT           1.681498
# COWPEA           5.183983
# LETTUCE          0.529520
# MANGO            0.111007
# OAT              0.848433
# ORANGE JUICE     1.773354
# SOY BURGER       1.194030
# SOYBEAN          1.243387
# SUNFLOWER OIL    0.185898
# dtype: float64

# %% [markdown]
# ### **[X]: Cost comparison: Co2 emissions**

# %%
#CO2 Omnivore
df['Price with Co2 Social Cost per 100g (USD)'] = (0.0185 * df['Carbon Footprint kg CO2eq/kg or l of food ITEM']) + df['Average Price per 100g (USD)']

price_cotwo_col = 'Price with Co2 Social Cost per 100g (USD)'
group = "F 19-30"
diet = 'not vegan'

solution = get_grub(group, diet, df, price_cotwo_col)
# Out:
# Cost of diet for F 19-30 with a(n) not vegan diet, controlling for C02 social cost is $3.47 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# CARROT           4.931957
# COW MILK         2.378574
# COWPEA           2.406439
# LETTUCE          0.061459
# MANGO            0.655301
# OAT              0.960015
# SOY BURGER       1.194030
# SOYBEAN          1.131157
# SUNFLOWER OIL    0.155631
# dtype: float64

# %%
#CO2 Vegan
df['Price with Co2 Social Cost per 100g (USD)'] = (0.0185 * df['Carbon Footprint kg CO2eq/kg or l of food ITEM']) + df['Average Price per 100g (USD)']

price_cotwo_col = 'Price with Co2 Social Cost per 100g (USD)'
group = "F 19-30"
diet = 'not vegan'


solution = get_grub(group, diet, df, price_cotwo_col)
# Out:
# Cost of diet for F 19-30 with a(n) not vegan diet, controlling for C02 social cost is $3.47 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# CARROT           4.931957
# COW MILK         2.378574
# COWPEA           2.406439
# LETTUCE          0.061459
# MANGO            0.655301
# OAT              0.960015
# SOY BURGER       1.194030
# SOYBEAN          1.131157
# SUNFLOWER OIL    0.155631
# dtype: float64

# %%
#Water Omnivore
water_col = 'Water Footprint liters water/kg o liter of food ITEM'
group = "F 19-30"
diet = 'not vegan'


solution = get_grub(group, diet, df, water_col)
# Out:
# Cost of diet for F 19-30 with a(n) not vegan diet, controlling for Water footprint is $11.85 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# BLACKBERRY        0.255939
# CARROT            7.389950
# CURRANT           1.676870
# EGGPLANT          0.482490
# SOY BURGER        0.040215
# SUNFLOWER OIL     0.037028
# TOMATO & BASIL    7.415913
# dtype: float64

# %%
#Water vegan
water_col = 'Water Footprint liters water/kg o liter of food ITEM'
group = "F 19-30"
diet = 'vegan'


solution = get_grub(group, diet, df, water_col)
# Out:
# Cost of diet for F 19-30 with a(n) vegan diet, controlling for Water footprint is $11.85 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# BLACKBERRY        0.255939
# CARROT            7.389950
# CURRANT           1.676870
# EGGPLANT          0.482490
# SOY BURGER        0.040215
# SUNFLOWER OIL     0.037028
# TOMATO & BASIL    7.415913
# dtype: float64

# %% [markdown]
# ### **[B]: Is your solution edible?**

# %% [markdown]
# Yes, our solution is edible! Here is our recipe:
#
# **Potato Sliders:**
#
# > Prepare the Potato Buns: <br>
#
# >> Slice the potatoes into even, bun-sized rounds (about ½-inch thick). <br>
# >> Heat the oil in a skillet over medium heat. Fry the potato slices until golden brown and crispy, about 3-4 minutes per side. Remove and drain on paper towels. <br>
#
# > Prepare the Vegetables: <br>
#
# >> Thinly slice the carrot into small rectangles. <br>
# >>Wash and chop the lettuce into smaller pieces. <br>
# >> Boil the peas until tender, then set aside for garnish. <br>
#
# > Cook the Burger Patties: <br>
#
# >> In the same skillet, cook the burger patties over medium-high heat until fully cooked, about 3-4 minutes per side, depending on thickness. <br>
#
# > Assemble the Sliders: <br>
#
# >> Place a fried potato slice as the bottom "bun." <br>
# >>Add a cooked burger patty. <br>
# >> Layer with lettuce and carrot slices. <br>
# >> Top with another fried potato slice as the "bun." <br>
# >> Garnish with boiled peas on top or around the plate <br>

# %% [markdown]
# ### **[B]: What is total cost for population of interest?**

# %% [markdown]
# **Population function:**

# %%
countries = wbdata.get_countries()
country_dict = {}

for country in countries:
    country_code = country['id']
    country_name = country['name']
    country_dict[country_name] = country_code

def int_to_str(num):
    if 0 <= num < 10:
        return f"0{num}"
    else:
        return str(num)

def population_range(year, sex, age_range, place):
    sex_codes = {"people": "", "females": "FE", "males": "MA"}
    sex_used = sex_codes[sex]
    lower, upper = int_to_str(age_range[0]), int_to_str(age_range[1])
    range_string = lower + upper
    country_code = country_dict.get(place)
    df = wbdata.get_dataframe({"SP.POP." + range_string + "." + sex_used: "Population"},
                              country= {country_code: place}).squeeze()
    df = df.to_frame().reset_index()
    population_total = int(df[df["date"] == str(year)]["Population"].iloc[0])
    return population_total

def over_80_pop(year, sex, place):
    sex_codes = {"people": "", "females": "FE", "males": "MA"}
    sex_used = sex_codes[sex]
    country_code = country_dict.get(place)

    df = wbdata.get_dataframe({"SP.POP." + "80UP" + "." + sex_used: "Population"},
                              country= {country_code: place}).squeeze()
    df = df.to_frame().reset_index()
    population_total = int(df[df["date"] == str(year)]["Population"].iloc[0])
    return population_total

def dict_helper(year, sex, age_range, place):
    if len(age_range) == 1:
        age_range = [age_range[0], age_range[0]]
    elif age_range[1] < age_range[0]:
      raise ValueError(f"Please ensure that the second value in the range is greater than the first.")

    minimum_age, maximum_age = age_range
    possible_minimums = [i for i in range(0, 76, 5)]
    possible_maximums = [i for i in range(4, 80, 5)]

    my_dict = {}
    for age in range(minimum_age, maximum_age + 1):
        range_index = next((i for i, min_val in enumerate(possible_minimums) if
                            min_val <= age and age <= possible_maximums[i]), None)
        if range_index is not None:
            popl_value = population_range(year, sex, [possible_minimums[range_index], possible_maximums[range_index]], place) // 5
            my_dict[age] = popl_value
        elif age >= 80 and age <= 100:
            my_dict[age] = over_80_pop(year, sex, place) / 20
        else:
            raise ValueError(f"No age range available for age {age}")
    return my_dict

def population(year, sex = "all", age_range = [0,100], place = "World"):
    if place not in country_dict:
        valid_regions = ", ".join(country_dict.keys())
        raise ValueError(f"The region '{place}' is not valid. Please choose from the following regions: {valid_regions}")
    if sex in ["all", "people", "p", "P", "People", "All", "Everyone"]:
      female_dict = dict_helper(year, "females", age_range, place)
      male_dict = dict_helper(year, "males", age_range, place)
      return sum(female_dict.values()) + sum(male_dict.values())
    elif sex in ["female", "females", "f", "Female", "Females", "F", "FE"]:
      female_dict = dict_helper(year, "females", age_range, place)
      return sum(female_dict.values())
    elif sex in ["male", "males", "m", "Male", "Males", "M", "MA"]:
      male_dict = dict_helper(year, "males", age_range, place)
      return sum(male_dict.values())

# %% [markdown]
# **Dataframe:**

# %%
def create_population_dataframe(regions, years, age_range):
    data = []

    if len(age_range) == 1:
        full_age_range = [age_range[0]]
    else:
        full_age_range = list(range(age_range[0], age_range[1] + 1))

    for region in regions:
        for year in years:
            row = {'Region': region, 'Year': year}
            for age in full_age_range:
                male_population = population(year, 'male', [age], region)
                female_population = population(year, 'female', [age], region)

                row[f'Male Population Age {age}'] = male_population
                row[f'Female Population Age {age}'] = female_population
            data.append(row)

    df = pd.DataFrame(data)
    df.set_index(['Region', 'Year'], inplace=True)
    return df

# %%
usa_pop_df = create_population_dataframe(["United States"], [2023], [0, 80])

groupings = {
    "C 1-3": [
        "Male Population Age 1", "Male Population Age 2", "Male Population Age 3",
        "Female Population Age 1", "Female Population Age 2", "Female Population Age 3"
    ],
    "F 4-8": [
        "Female Population Age 4", "Female Population Age 5", "Female Population Age 6",
        "Female Population Age 7", "Female Population Age 8"
    ],
    "M 4-8": [
        "Male Population Age 4", "Male Population Age 5", "Male Population Age 6",
        "Male Population Age 7", "Male Population Age 8"
    ],
    "F 9-13": [
        "Female Population Age 9", "Female Population Age 10", "Female Population Age 11",
        "Female Population Age 12", "Female Population Age 13"
    ],
    "M 9-13": [
        "Male Population Age 9", "Male Population Age 10", "Male Population Age 11",
        "Male Population Age 12", "Male Population Age 13"
    ],
    "F 14-18": [
        "Female Population Age 14", "Female Population Age 15", "Female Population Age 16",
        "Female Population Age 17", "Female Population Age 18"
    ],
    "M 14-18": [
        "Male Population Age 14", "Male Population Age 15", "Male Population Age 16",
        "Male Population Age 17", "Male Population Age 18"
    ],
    "F 19-30": [
        "Female Population Age 19", "Female Population Age 20", "Female Population Age 21",
        "Female Population Age 22", "Female Population Age 23", "Female Population Age 24",
        "Female Population Age 25", "Female Population Age 26", "Female Population Age 27",
        "Female Population Age 28", "Female Population Age 29", "Female Population Age 30"
    ],
    "M 19-30": [
        "Male Population Age 19", "Male Population Age 20", "Male Population Age 21",
        "Male Population Age 22", "Male Population Age 23", "Male Population Age 24",
        "Male Population Age 25", "Male Population Age 26", "Male Population Age 27",
        "Male Population Age 28", "Male Population Age 29", "Male Population Age 30"
    ],
    "F 31-50": [
        "Female Population Age 31", "Female Population Age 32", "Female Population Age 33",
        "Female Population Age 34", "Female Population Age 35", "Female Population Age 36",
        "Female Population Age 37", "Female Population Age 38", "Female Population Age 39",
        "Female Population Age 40", "Female Population Age 41", "Female Population Age 42",
        "Female Population Age 43", "Female Population Age 44", "Female Population Age 45",
        "Female Population Age 46", "Female Population Age 47", "Female Population Age 48",
        "Female Population Age 49", "Female Population Age 50"
    ],
    "M 31-50": [
        "Male Population Age 31", "Male Population Age 32", "Male Population Age 33",
        "Male Population Age 34", "Male Population Age 35", "Male Population Age 36",
        "Male Population Age 37", "Male Population Age 38", "Male Population Age 39",
        "Male Population Age 40", "Male Population Age 41", "Male Population Age 42",
        "Male Population Age 43", "Male Population Age 44", "Male Population Age 45",
        "Male Population Age 46", "Male Population Age 47", "Male Population Age 48",
        "Male Population Age 49", "Male Population Age 50"
    ],
    "F 51+": [
        "Female Population Age 51", "Female Population Age 52", "Female Population Age 53",
        "Female Population Age 54", "Female Population Age 55", "Female Population Age 56",
        "Female Population Age 57", "Female Population Age 58", "Female Population Age 59",
        "Female Population Age 60", "Female Population Age 61", "Female Population Age 62",
        "Female Population Age 63", "Female Population Age 64", "Female Population Age 65",
        "Female Population Age 66", "Female Population Age 67", "Female Population Age 68",
        "Female Population Age 69", "Female Population Age 70", "Female Population Age 71",
        "Female Population Age 72", "Female Population Age 73", "Female Population Age 74",
        "Female Population Age 75", "Female Population Age 76", "Female Population Age 77",
        "Female Population Age 78", "Female Population Age 79", "Female Population Age 80"
    ],
    "M 51+": [
        "Male Population Age 51", "Male Population Age 52", "Male Population Age 53",
        "Male Population Age 54", "Male Population Age 55", "Male Population Age 56",
        "Male Population Age 57", "Male Population Age 58", "Male Population Age 59",
        "Male Population Age 60", "Male Population Age 61", "Male Population Age 62",
        "Male Population Age 63", "Male Population Age 64", "Male Population Age 65",
        "Male Population Age 66", "Male Population Age 67", "Male Population Age 68",
        "Male Population Age 69", "Male Population Age 70", "Male Population Age 71",
        "Male Population Age 72", "Male Population Age 73", "Male Population Age 74",
        "Male Population Age 75", "Male Population Age 76", "Male Population Age 77",
        "Male Population Age 78", "Male Population Age 79", "Male Population Age 80"
    ]
}

# Loop through each group and sum the relevant columns
for group, cols in groupings.items():
    usa_pop_df[group] = usa_pop_df[cols].sum(axis=1)

# After summing the populations, drop the original age columns
columns_to_drop = [col for sublist in groupings.values() for col in sublist]
usa_pop_df.drop(columns=columns_to_drop, inplace=True)
usa_pop_df
# Out:
#                     Male Population Age 0  Female Population Age 0     C 1-3  \
# Region        Year
# United States 2023                1859555                  1776227  10907346
#
#                       F 4-8    M 4-8    F 9-13    M 9-13   F 14-18   M 14-18  \
# Region        Year
# United States 2023  9500935  9992427  10058653  10646674  10579645  11242472
#
#                      F 19-30   M 19-30   F 31-50   M 31-50        F 51+  \
# Region        Year
# United States 2023  25700622  27479410  43051959  45568239  53186441.55
#
#                          M 51+
# Region        Year
# United States 2023  50890359.2

# %% [markdown]
# **Total Cost Function:**

# %% [markdown]
# Parameter can be `price`, `co2`, or `water`. Must run *Cost Comparison* cells before runnning this function.

# %%
def total_cost_pop(sex_age_group, diet, df, parameter='price'):
    
    old_stdout = sys.stdout
    sys.stdout = io.StringIO()
    
    try:
        if parameter == 'price':
            _, total_cost = get_grub(sex_age_group, diet, df)
        elif parameter == 'co2':
            _, total_cost = get_grub_cotwo(sex_age_group, diet, df)
        elif parameter == 'water':
            _, total_cost = get_grub_water(sex_age_group, diet, df)
        else:
            return "Invalid parameter."
        
        pop_total = usa_pop_df.loc[('United States', 2023), sex_age_group]
        total_cost *= pop_total
        
    finally:
        sys.stdout = old_stdout
    
    return f"The total cost of this population is ${total_cost:.2f}."

# %%
test_totcost = total_cost_pop('F 19-30', 'not vegan', df, 'price')
test_totcost
# Out:
# 'The total cost of this population is $84738817.75.'

# %%
# Unit Test: Outputted value equals expected value for (population total)(cost per person)
assert float(test_totcost.split('$')[1].strip('.')) == round(25700622 * 3.297150463772697, 2)

# %% [markdown]
# ### **[C]: Sensitivity of Solution**

# %%
#Suppose a crazy flu hit birds and the price of eggs shot up. Write a function that allows to enter a food name and the % increase, to see how that might chagne the suggested diet
def price_sensitivity(food_name, percent_increase, group, diet, df):
    '''
    param food_name: The name of the food to update.
    :param percent_increase: The percentage increase to apply (e.g., 10 for 10%).
    '''
    df_copy = df.copy()
    
    multiplier = 1 + percent_increase / 100
    
    if 'Food' in df_copy.columns:
        #access column
        mask = df_copy['Food'].str.contains(food_name, case=False, na=False)
    elif df_copy.index.name == 'Food':
        #access index
        mask = df_copy.index.str.contains(food_name, case=False, na=False)
    else:
        raise ValueError("The DataFrame does not contain a 'Food' column or index.")
    
    # Update the price per kg in the copy
    print(df_copy.loc[mask, 'Average Price per 100g (USD)'])
  
    df_copy.loc[mask, 'Average Price per kg (USD)'] *= multiplier
    # Update the price per 100g in the copy
    df_copy.loc[mask, 'Average Price per 100g (USD)'] *= multiplier
    print(df_copy.loc[mask, 'Average Price per 100g (USD)'])
    solution = get_grub(group, diet, df_copy)




group = "F 19-30"
diet = 'not vegan'
price_sensitivity('cow milk', 20, group, diet, df)
# Out:
# Food
# COW MILK    0.105
# Name: Average Price per 100g (USD), dtype: float64
# Food
# COW MILK    0.126
# Name: Average Price per 100g (USD), dtype: float64
# Cost of diet for F 19-30 is $3.35 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# CARROT           1.917974
# COW MILK         1.918741
# COWPEA           5.247463
# LETTUCE          0.507813
# MANGO            0.043735
# OAT              0.849315
# SOY BURGER       1.194030
# SOYBEAN          1.188369
# SUNFLOWER OIL    0.183949
# dtype: float64

# %%
alpha = 0.1

#social cost of a ton of carbon is $185 so 0.0185 per 100 g
df['Price with Co2 Social Cost per 100g (USD)'] = (0.0185 * df['Carbon Footprint kg CO2eq/kg or l of food ITEM']) + df['Average Price per 100g (USD)']

def get_grub_cotwo(sex_age_group, diet, df):
    if (diet == 'animal product'):
        df = df[df['animal product'] == 'animal product']
    D = {}
    count = 0
    
    
    for food in df.index:
        try:
            FDC = df.loc[df.index==food,:]['FDC ID'][0]
            count+=1
            D[food] = fdc.nutrients(apikey,FDC).Quantity
            #print(D[food])
            #print(food)
        except AttributeError:
            warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")
    
    D = pd.DataFrame(D,dtype=float)
    df.dropna(how='any') # Drop food with any missing data

    Prices = df.groupby('Food')['Price with Co2 Social Cost per 100g (USD)'].min()
    p = Prices.apply(lambda x:x).dropna()
    
    # Compile list that we have both prices and nutritional info for; drop if either missing
    use = p.index.intersection(D.columns)
    p = p[use]
    tol = 1e-6 # Numbers in solution smaller than this (in absolute value) treated as zeros

    Aall = D[p.index].fillna(0)
    display(Aall)
    # Drop rows of A that we don't have constraints for.
    Amin = Aall.loc[bmin.index]
    
    Amax = Aall.loc[bmax.index]
    
    # Maximum requirements involve multiplying constraint by -1 to make <=.
    A = pd.concat([Amin,-Amax])
    ## Choose sex/age group!
    result =  lp(p, -A, -b[sex_age_group], method='highs')
    total_cost = result.fun
    print(f"Cost of diet for {group} considering Co2 social cost is ${result.fun:.2f} per day.")
    # Put back into nice series
    diet = pd.Series(result.x,index=p.index)
    
    print("\nYou'll be eating (in 100s of grams or milliliters):")
    print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.
    return diet, total_cost

group = "F 19-30"
diet = 'omnivore'
#result = get_grub(group, diet, df)

solution = get_grub_cotwo(group, diet, df)
# Out:
#                                   APPLE  APRICOT  ARTICHOKE  AVOCADO  BACON  \
# Alanine                             0.0      0.0        0.0     0.00    0.0
# Alcohol, ethyl                      0.0      0.0        0.0     0.00    0.0
# Amino acids                         0.0      0.0        0.0     0.00    0.0
# Arginine                            0.0      0.0        0.0     0.00    0.0
# Ash                                 0.0      0.0        0.0     0.00    0.0
# ...                                 ...      ...        ...      ...    ...
# Vitamin K (Dihydrophylloquinone)    0.0      0.0        0.0     0.00    0.0
# Vitamin K (phylloquinone)           0.0      0.0       14.8    21.00    0.0
# Vitamins and Other Components       0.0      0.0        0.0     0.00    0.0
# Water                               0.0      0.0       84.1    73.20    0.0
# Zinc, Zn                            0.0      0.0        0.4     0.64    0.0
#
#                                   BANANA  BARLEY   BEAN  BEANS (F)  \
# Alanine                              0.0    0.00   0.00       0.00
# Alcohol, ethyl                       0.0    0.00   0.00       0.00
# Amino acids                          0.0    0.00   0.00       0.00
# Arginine                             0.0    0.00   0.00       0.00
# Ash                                  0.0    0.00   0.00       0.00
# ...                                  ...     ...    ...        ...
# Vitamin K (Dihydrophylloquinone)     0.0    0.00   0.00       0.00
# Vitamin K (phylloquinone)            0.0    2.10   1.70       1.70
# Vitamins and Other Components        0.0    0.00   0.00       0.00
# Water                                0.0   67.10  73.00      73.00
# Zinc, Zn                             0.0    0.79   0.69       0.69
#
#                                   BEEF BONE FREE MEAT*  ...  TOMATO PEELED  \
# Alanine                                            0.0  ...            0.0
# Alcohol, ethyl                                     0.0  ...            0.0
# Amino acids                                        0.0  ...            0.0
# Arginine                                           0.0  ...            0.0
# Ash                                                0.0  ...            0.0
# ...                                                ...  ...            ...
# Vitamin K (Dihydrophylloquinone)                   0.0  ...            0.0
# Vitamin K (phylloquinone)                          1.7  ...            0.0
# Vitamins and Other Components                      0.0  ...            0.0
# Water                                             56.3  ...            0.0
# Zinc, Zn                                           6.2  ...            0.0
#
#                                   TOMATO PUREE  TROUT  TURBOT  TURNIP  \
# Alanine                                    0.0   0.00   0.971   0.147
# Alcohol, ethyl                             0.0   0.00   0.000   0.000
# Amino acids                                0.0   0.00   0.000   0.000
# Arginine                                   0.0   0.00   0.960   0.128
# Ash                                        0.0   0.00   2.100   0.830
# ...                                        ...    ...     ...     ...
# Vitamin K (Dihydrophylloquinone)           0.0   0.00   0.000   0.000
# Vitamin K (phylloquinone)                  0.0  12.00   0.000   0.000
# Vitamins and Other Components              0.0   0.00   0.000   0.000
# Water                                      0.0  53.20  76.950  93.130
# Zinc, Zn                                   0.0   0.49   0.220   0.160
#
#                                   WATERMELON  WHEAT  WHOLEGRAIN CRACKERS**  \
# Alanine                                  0.0   0.00                   0.00
# Alcohol, ethyl                           0.0   0.00                   0.00
# Amino acids                              0.0   0.00                   0.00
# Arginine                                 0.0   0.00                   0.00
# Ash                                      0.0   0.00                   0.00
# ...                                      ...    ...                    ...
# Vitamin K (Dihydrophylloquinone)         0.0   0.00                   0.00
# Vitamin K (phylloquinone)                0.0   4.90                  36.00
# Vitamins and Other Components            0.0   0.00                   0.00
# Water                                    0.0  35.20                   2.50
# Zinc, Zn                                 0.0   1.04                   0.98
#
#                                   YOGURT WHITE  ZUCCHINI
# Alanine                                   0.00       0.0
# Alcohol, ethyl                            0.00       0.0
# Amino acids                               0.00       0.0
# Arginine                                  0.00       0.0
# Ash                                       0.00       0.0
# ...                                        ...       ...
# Vitamin K (Dihydrophylloquinone)          0.00       0.0
# Vitamin K (phylloquinone)                 0.00       0.0
# Vitamins and Other Components             0.00       0.0
# Water                                     0.00       0.0
# Zinc, Zn                                  0.62       0.0
#
# [133 rows x 126 columns]
# Cost of diet for F 19-30 considering Co2 social cost is $3.47 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# CARROT           4.931957
# COW MILK         2.378574
# COWPEA           2.406439
# LETTUCE          0.061459
# MANGO            0.655301
# OAT              0.960015
# SOY BURGER       1.194030
# SOYBEAN          1.131157
# SUNFLOWER OIL    0.155631
# dtype: float64

# %% [markdown]
# ### **[X]: Cost comparison: H2O emissions**

# %%
alpha = 0.1

#cost of H2O

def get_grub_water(sex_age_group, diet, df):
    if (diet == 'animal product'):
        df = df[df['animal product'] == 'animal product']
    D = {}
    count = 0
    
    
    for food in df.index:
        try:
            FDC = df.loc[df.index==food,:]['FDC ID'][0]
            count+=1
            D[food] = fdc.nutrients(apikey,FDC).Quantity
            #print(D[food])
            #print(food)
        except AttributeError:
            warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")
    
    D = pd.DataFrame(D,dtype=float)
    df.dropna(how='any') # Drop food with any missing data

    Prices = df.groupby('Food')['Water Footprint liters water/kg o liter of food ITEM'].min()
    p = Prices.apply(lambda x:x).dropna()
    
    # Compile list that we have both prices and nutritional info for; drop if either missing
    use = p.index.intersection(D.columns)
    p = p[use]
    tol = 1e-6 # Numbers in solution smaller than this (in absolute value) treated as zeros

    Aall = D[p.index].fillna(0)
    display(Aall)
    # Drop rows of A that we don't have constraints for.
    Amin = Aall.loc[bmin.index]
    
    Amax = Aall.loc[bmax.index]
    
    # Maximum requirements involve multiplying constraint by -1 to make <=.
    A = pd.concat([Amin,-Amax])
    ## Choose sex/age group!
    result =  lp(p, -A, -b[sex_age_group], method='highs')
    total_cost = result.fun
    print(f"Cost of diet for {group} considering H2O cost is ${result.fun:.2f} per day.")
    # Put back into nice series
    diet = pd.Series(result.x,index=p.index)
        
    print("\nYou'll be eating (in 100s of grams or milliliters):")
    print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.
    return diet, total_cost

group = "F 19-30"
diet = 'omnivore'
#result = get_grub(group, diet, df)

solution = get_grub_water(group, diet, df)
# Out:
#                                   APPLE  APRICOT  ARTICHOKE  AVOCADO  BACON  \
# Alanine                             0.0      0.0        0.0     0.00    0.0
# Alcohol, ethyl                      0.0      0.0        0.0     0.00    0.0
# Amino acids                         0.0      0.0        0.0     0.00    0.0
# Arginine                            0.0      0.0        0.0     0.00    0.0
# Ash                                 0.0      0.0        0.0     0.00    0.0
# ...                                 ...      ...        ...      ...    ...
# Vitamin K (Dihydrophylloquinone)    0.0      0.0        0.0     0.00    0.0
# Vitamin K (phylloquinone)           0.0      0.0       14.8    21.00    0.0
# Vitamins and Other Components       0.0      0.0        0.0     0.00    0.0
# Water                               0.0      0.0       84.1    73.20    0.0
# Zinc, Zn                            0.0      0.0        0.4     0.64    0.0
#
#                                   BANANA  BARLEY   BEAN  BEANS (F)  \
# Alanine                              0.0    0.00   0.00       0.00
# Alcohol, ethyl                       0.0    0.00   0.00       0.00
# Amino acids                          0.0    0.00   0.00       0.00
# Arginine                             0.0    0.00   0.00       0.00
# Ash                                  0.0    0.00   0.00       0.00
# ...                                  ...     ...    ...        ...
# Vitamin K (Dihydrophylloquinone)     0.0    0.00   0.00       0.00
# Vitamin K (phylloquinone)            0.0    2.10   1.70       1.70
# Vitamins and Other Components        0.0    0.00   0.00       0.00
# Water                                0.0   67.10  73.00      73.00
# Zinc, Zn                             0.0    0.79   0.69       0.69
#
#                                   BEEF BONE FREE MEAT*  ...  TOMATO PEELED  \
# Alanine                                            0.0  ...            0.0
# Alcohol, ethyl                                     0.0  ...            0.0
# Amino acids                                        0.0  ...            0.0
# Arginine                                           0.0  ...            0.0
# Ash                                                0.0  ...            0.0
# ...                                                ...  ...            ...
# Vitamin K (Dihydrophylloquinone)                   0.0  ...            0.0
# Vitamin K (phylloquinone)                          1.7  ...            0.0
# Vitamins and Other Components                      0.0  ...            0.0
# Water                                             56.3  ...            0.0
# Zinc, Zn                                           6.2  ...            0.0
#
#                                   TOMATO PUREE  TROUT  TURBOT  TURNIP  \
# Alanine                                    0.0   0.00   0.971   0.147
# Alcohol, ethyl                             0.0   0.00   0.000   0.000
# Amino acids                                0.0   0.00   0.000   0.000
# Arginine                                   0.0   0.00   0.960   0.128
# Ash                                        0.0   0.00   2.100   0.830
# ...                                        ...    ...     ...     ...
# Vitamin K (Dihydrophylloquinone)           0.0   0.00   0.000   0.000
# Vitamin K (phylloquinone)                  0.0  12.00   0.000   0.000
# Vitamins and Other Components              0.0   0.00   0.000   0.000
# Water                                      0.0  53.20  76.950  93.130
# Zinc, Zn                                   0.0   0.49   0.220   0.160
#
#                                   WATERMELON  WHEAT  WHOLEGRAIN CRACKERS**  \
# Alanine                                  0.0   0.00                   0.00
# Alcohol, ethyl                           0.0   0.00                   0.00
# Amino acids                              0.0   0.00                   0.00
# Arginine                                 0.0   0.00                   0.00
# Ash                                      0.0   0.00                   0.00
# ...                                      ...    ...                    ...
# Vitamin K (Dihydrophylloquinone)         0.0   0.00                   0.00
# Vitamin K (phylloquinone)                0.0   4.90                  36.00
# Vitamins and Other Components            0.0   0.00                   0.00
# Water                                    0.0  35.20                   2.50
# Zinc, Zn                                 0.0   1.04                   0.98
#
#                                   YOGURT WHITE  ZUCCHINI
# Alanine                                   0.00       0.0
# Alcohol, ethyl                            0.00       0.0
# Amino acids                               0.00       0.0
# Arginine                                  0.00       0.0
# Ash                                       0.00       0.0
# ...                                        ...       ...
# Vitamin K (Dihydrophylloquinone)          0.00       0.0
# Vitamin K (phylloquinone)                 0.00       0.0
# Vitamins and Other Components             0.00       0.0
# Water                                     0.00       0.0
# Zinc, Zn                                  0.62       0.0
#
# [133 rows x 126 columns]
# Cost of diet for F 19-30 considering H2O cost is $3942.14 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# BLACKBERRY        0.255939
# CARROT            7.389950
# CURRANT           1.676870
# EGGPLANT          0.482490
# SOY BURGER        0.040215
# SUNFLOWER OIL     0.037028
# TOMATO & BASIL    7.415913
# dtype: float64
