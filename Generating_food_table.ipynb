# %%
import pandas as pd

tbl1 = pd.read_csv('SuEatableLife_Food_Fooprint_database.xlsx - SEL CF for users.csv')
# omnivore_recipe = (omnivore_recipe).assign(ingred_code = lambda df: df["ingred_code"].apply(format_id).rename(columns={"parent_desc": "recipe"}))

# %%
tbl2 = pd.read_csv('SuEatableLife_Food_Fooprint_database.xlsx - SEL WF for users.csv')
# omnivore_recipe = (omnivore_recipe).assign(ingred_code = lambda df: df["ingred_code"].apply(format_id).rename(columns={"parent_desc": "recipe"}))

# %%
# Merged SUEatableLife tables
import pandas as pd 

merged_tbls = pd.merge(tbl1, tbl2, on=["Food commodity ITEM", "Food commodity ITEM"], how="inner")

# Save the merged result to a new CSV file
merged_tbls.to_csv("merged_output.csv", index=False)
merged_tbls

# %%
# %pip install -r requirements.txt --upgrade
import fooddatacentral as fdc

# %%
apikey = "KNqUDtV7Kcktiuheo3EoNhB0zDlCevFAdqZrKgdj" 



fd = merged_tbls
#df = pd.read_csv("cf-sueatable.csv")
#cf_sueatable

food_cleaned =  'chocolate or cream filled cookies'
result = fdc.search(apikey, food_cleaned)  # Search for the food item

'''
if len(result) > 0:  # Ensure it's a list with results
    fdc_id = result[0]['fdcId']  # Extract FDC ID from the first match
    print(f'{result[0]=}')
'''
fdc_id = int(result.loc[0]['fdcId'])
result

# %%
import regex as re



# Load your CSV into a DataFrame (assuming you have already done this)
#cf_sueatable = pd.read_csv("cf-sueatable.csv")  # Uncomment if loading from a file

# Initialize an empty dictionary to store FDC results
# Assuming df is already loaded
food_column = fd.columns[1]  # Get the first column name

# Function to normalize food names (remove special characters)
def normalize_food_name(food):
    return re.sub(r"[^\w\s]", "", food).strip().lower()  # Remove non-alphanumeric chars

# Initialize an empty list to store FDC IDs
fdc_ids = []
fdc_names = []
# Loop through each row in the first column
for food in fd[food_column]:
    #try:
        food_cleaned = normalize_food_name(str(food))  # Normalize food name
        #print(f'{food_cleaned=}')
        result = fdc.search(apikey, food_cleaned)  # Search for the food item
        
        if len(result) > 0:  # Ensure it's a list with results
            fdc_id = int(result.loc[0]['fdcId'])  # Extract FDC ID from the first match
            fdc_name = result.loc[0]['description']
            #print(f'{fdc_id=}')
            #print(f'{fdc_name=}')
        else:
            fdc_id = None  # If no result, store None
    


        fdc_ids.append(fdc_id)  # Append the result to the list
        fdc_names.append(fdc_name)
# Add the FDC IDs as a new column in the DataFrame
fd["FDC ID"] = fdc_ids
fd["FDC Food Name"] = fdc_names
#df2 = fd[fd["FDC"] != None]
#df2

# %%
columns_to_keep = [1, 2, 10, 17,18]

# Drop columns by index
#fd2 = fd.iloc[:, columns_to_keep]
fd2.loc[100:]

# %%
fd2.at[0, 'FDC ID'] = 2707915
fd2.at[0, 'FDC Food Name'] ='Cookie, chocolate or fudge'
fd2.at[2, 'FDC ID'] = 2707777	
fd2.at[2, 'FDC Food Name'] ='Bread, multigrain'
fd2.at[1, 'FDC ID'] = 2707964	
fd2.at[1, 'FDC Food Name'] ='Cookie, shortbread'
fd2.at[7, 'FDC ID'] = 2708170	
fd2.at[7, 'FDC Food Name'] ='Crackers, multigrain'
fd2.at[12, 'FDC ID'] = 2708398	
fd2.at[12, 'FDC Food Name'] ='Oatmeal, multigrain'
fd2.at[25, 'FDC ID'] = 2710071		
fd2.at[25, 'FDC Food Name'] ='Beets, pickled'
fd2.at[29, 'FDC ID'] = 2303724		
fd2.at[29, 'FDC Food Name'] = 'PEELED TOMATOES'
fd2.at[35, 'FDC ID'] = 174287		
fd2.at[35, 'FDC Food Name'] = 'Veggie burgers or soyburgers, unprepared'
fd2.at[38, 'FDC ID'] = 2705854		
fd2.at[38, 'FDC Food Name'] = 'Beef, ground'	
fd2.at[40, 'FDC ID'] = 2705597		
fd2.at[40, 'FDC Food Name'] = 'Cream, heavy'	

fd2.loc[49, ['FDC ID', 'FDC Food Name']] = [2705907, 'Lamb, ground']
fd2.loc[48, ['FDC ID', 'FDC Food Name']] = [1458338, 'LAMB BONE-IN LAMB LEGS']
fd2.loc[50, ['FDC ID', 'FDC Food Name']] = [2658737	, 'MILK']
fd2.loc[53, ['FDC ID', 'FDC Food Name']] = [2706091, 'Chicken, ground']
fd2.loc[54, ['FDC ID', 'FDC Food Name']] = [2554062, 'YOGURT']
fd2.loc[63, ['FDC ID', 'FDC Food Name']] = [2709223, 'Avocado, raw']
fd2.loc[83, ['FDC ID', 'FDC Food Name']] = [2708376	,'Masa harina, cooked']	
fd2.loc[85, ['FDC ID', 'FDC Food Name']] = [2708489,'Oats, raw']	

fd2.loc[94, ['FDC ID', 'FDC Food Name']] = [174271,	'Soybeans, mature cooked, boiled, without salt']
fd2.loc[93, ['FDC ID', 'FDC Food Name']] = [170419,	'Peas, green, raw']	
fd2.loc[97, ['FDC ID', 'FDC Food Name']] = [2707505	,'Mixed nuts, unroasted']	

fd2.loc[104, ['FDC ID', 'FDC Food Name']] = [2710790,'Potato, cooked, as ingredient']	
fd2.loc[106, ['FDC ID', 'FDC Food Name']] = [169975	,'Cabbage, raw']

# %%
#fd2.to_csv("food_list.csv", index=False)

# %%
#AI estimates
fd2['Average Price per kg (USD)'] = [
    10.80,  # 1. Cookie, chocolate or fudge
    10.80,  # 2. Cookie, shortbread
    4.24,   # 3. Bread, multigrain
    4.24,   # 4. Bread, sticks, plain
    4.24,   # 5. Bread, whole wheat
    8.80,   # 6. FLAVORED CRACKERS
    8.80,   # 7. Crackers, butter, plain
    8.80,   # 8. Crackers, multigrain
    8.80,   # 9. CRISPBREAD
    2.20,   # 10. Ketchup
    3.00,   # 11. EGG PASTA
    1.50,   # 12. ORANGE JUICE
    3.50,   # 13. Oatmeal, multigrain
    15.00,  # 14. CHOCOLATE
    3.00,   # 15. Bean dip, made with refried beans
    3.50,   # 16. MARGARINE
    8.80,   # 17. Olive oil
    4.40,   # 18. Oil, palm
    4.40,   # 19. Peanut oil
    4.40,   # 20. RAPESEED OIL
    2.20,   # 21. Soybean oil
    4.40,   # 22. Sunflower oil
    2.20,   # 23. PASTA
    12.00,  # 24. PESTO
    12.00,  # 25. Pesto sauce
    2.20,   # 26. Beets, pickled
    1.50,   # 27. CANE SUGAR
    8.80,   # 28. Croissant
    8.80,   # 29. Croissant (duplicate)
    2.20,   # 30. PEELED TOMATOES
    2.20,   # 31. TOMATO PUREE
    12.00,  # 32. Mozzarella cheese, tomato, and basil, with oil and vinegar dressing
    4.40,   # 33. ARRABBIATA SPICY TOMATO SAUCE, ARRABBIATA
    2.20,   # 34. Corn, canned, cooked with oil
    10.00,  # 35. BREADED CHIK'N CUTLETS
    8.80,   # 36. Veggie burgers or soyburgers, unprepared
    4.40,   # 37. TOFU
    2.20,   # 38. Leavening agents, yeast, baker's, compressed
    12.00,  # 39. Beef, ground
    8.80,   # 40. BUTTER
    6.60,   # 41. Cream, heavy
    12.00,  # 42. MASCARPONE
    12.00,  # 43. MOZZARELLA
    8.80,   # 44. Cheese, Ricotta
    12.00,  # 45. CRESCENZA STRACCHINO, CRESCENZA
    12.00,  # 46. CHEESE
    20.00,  # 47. PARMIGIANO REGGIANO
    15.00,  # 48. COCONUT BRITTLE BUGITOS, COCONUT BRITTLE
    15.00,  # 49. LAMB BONE-IN LAMB LEGS
    15.00,  # 50. Lamb, ground
    1.05,   # 51. MILK
    6.60,   # 52. Pork, bones
    12.00,  # 53. BACON
    8.80,   # 54. Chicken, ground
    3.50,   # 55. YOGURT
    3.00,   # 56. CLEMENTINE
    2.20,   # 57. LEMON
    10.00,  # 58. Lime souffle
    3.00,   # 59. Mandarin, seedless, peeled, raw
    2.20,   # 60. ORANGE
    3.00,   # 61. Tangerine, raw
    2.20,   # 62. APPLE
    3.00,   # 63. APRICOT
    4.40,   # 64. Avocado, raw
    1.50,   # 65. BANANA
    4.40,   # 66. FIG
    4.40,   # 67. GRAPES
    4.40,   # 68. GUAVA
    4.40,   # 69. KIWI
    3.00,   # 70. MANGO
    3.00,   # 71. PEACH
    2.20,   # 72. Pear, raw
    2.20,   # 73. PINEAPPLE
    3.00,   # 74. Plum, raw
    1.50,   # 75. WATERMELON
    6.60,   # 76. BLACKBERRY
    6.60,   # 77. BLUEBERRY
    6.60,   # 78. CRANBERRY
    8.80,   # 79. Currants, dried
    6.60,   # 80. Gooseberries, raw
    6.60,   # 81. RASPBERRY
    4.40,   # 82. STRAWBERRY
    2.20,   # 83. Barley
    2.20,   # 84. Masa harina, cooked
    2.20,   # 85. Millet
    2.20,   # 86. Oats, raw
    2.20,   # 87. RYE
    2.20,   # 88. Sorghum grain
    4.24,   # 89. Bread, wheat or cracked wheat
    3.00,   # 90. Bean dip, made with refried beans (duplicate of 15)
    2.20,   # 91. CHICKPEA
    2.20,   # 92. Cowpeas, leafy tips, raw
    3.00,   # 93. Lentil curry
    2.20,   # 94. Peas, green, raw
    2.20,   # 95. Soybeans, mature cooked, boiled, without salt
    4.40,   # 96. CHESTNUT
    12.00,  # 97. MIXED NUTS
    12.00,  # 98. Mixed nuts, unroasted
    3.50,   # 99. PEANUT
    15.00,  # 100. PISTACHIO
    8.80,   # 101. Sesame seeds
    8.80,   # 102. Sunflower seeds, flavored
    6.60,   # 103. CHILLI POWDER BLEND, CHILLI
    6.60,   # 104. GINGER
    2.20,   # 105. Potato, cooked, as ingredient
    2.20,   # 106. SWEET POTATO
    1.50,   # 107. Cabbage, raw
    1.50,   # 108. Lettuce, raw
    2.20,   # 109. SPINACH
    1.50,   # 110. Carrots, raw
    10.00,  # 111. GARLIC
    2.20,   # 112. ONION
    2.20,   # 113. Turnip greens and turnips, frozen, unprepared
    4.40,   # 114. Artichoke
    2.20,   # 115. BROCCOLI
    2.20,   # 116. CAULIFLOWER
    3.00,   # 117. Cucumber salad made with cucumber and vinegar
    3.00,   # 118. Eggplant dip
    4.40,   # 119. PEPPER
    1.50,   # 120. PUMPKIN
    2.20,   # 121. TOMATO
    2.20,   # 122. ZUCCHINI
    8.80,   # 123. Fish, carp
    12.00,  # 124. COD
    20.00,  # 125. SALMON
    15.00,  # 126. Fish, trout, fried
    20.00   # 127. Fish, turbot, european, raw
]
#fd2.to_csv("food_and_prices.csv", index=False)
#::contentReference[oaicite:6]{index=6}

# %%
id = 2705854
fdc.nutrients(apikey,fdc_id=id)
